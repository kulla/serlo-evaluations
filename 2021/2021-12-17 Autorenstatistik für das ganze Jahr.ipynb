# %%
import pandas as pd
import mysql.connector

from IPython.display import display, Markdown, HTML

db = mysql.connector.connect(
    host="localhost",
    user="root",
    password="secret",
    port="3306",
    database="serlo"
)

d = pd.read_sql("""
    SELECT user.username, event_log.id, CASE
        WHEN event_id = 5 THEN "edits"
        WHEN event_id in (6,11) THEN "reviews"
        WHEN event_id in (8,9,14,16) THEN "comments"
        ELSE "taxonomy"
    END AS type
    FROM event_log
    join user on user.id = event_log.actor_id
    WHERE YEAR(event_log.date) = 2021
        AND event_log.event_id IN (5,6,11,8,9,14,16,1,2,12,15,17)
""", db)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

d = d.groupby(["username", "type"]).count()
d.sort_values(["id"], inplace=True, ascending=False)
d
# Out:
#                                             id
# username                        type
# WandaPaetzold                   reviews   5950
# Karin                           reviews   3084
# WandaPaetzold                   edits     2934
# kathongi                        reviews   2781
# LinaMaria                       reviews   2336
# kathongi                        edits     2296
# LinaMaria                       edits     2280
# kathongi                        taxonomy  2062
# Kowalsky                        edits     1852
# Rami                            edits     1806
# Peter                           reviews   1766
# LinaMaria                       taxonomy  1549
# Kowalsky                        reviews   1155
# Karin                           edits      979
# Gianluca                        edits      836
# Sascha_Lill_95                  reviews    750
# Annika-Hemlein                  edits      725
# metzgaria                       taxonomy   694
#                                 reviews    556
# Peter                           edits      540
# Sascha_Lill_95                  taxonomy   504
# Katrin_K                        edits      497
# MarK97                          edits      457
#                                 reviews    451
# Sascha_Lill_95                  edits      425
# HannaKulke                      edits      418
# Karin                           taxonomy   398
# Nish                            reviews    378
# Habiba                          edits      323
# Renate                          taxonomy   318
# Corinna                         edits      314
# metzgaria                       edits      310
# Corinna                         taxonomy   308
# Rami                            taxonomy   301
# dal                             edits      285
# Anton_Zikmund                   edits      268
# dal                             reviews    263
# Kowalsky                        taxonomy   256
# Nanami                          reviews    253
# dal                             taxonomy   249
# Louisa_H                        edits      242
# wolfgang                        reviews    240
# Gesine                          edits      237
#                                 taxonomy   233
#                                 reviews    203
# Max_                            edits      199
# Annika-Hemlein                  reviews    170
# KerstinPecher                   edits      155
# WandaPaetzold                   taxonomy   150
# Nish                            edits      146
# Gianluca                        taxonomy   141
# ABC19Z                          edits      139
# hxwalther                       edits      138
# Peter                           comments   137
# wolfgang                        taxonomy   136
# joshuae                         reviews    135
# Nanami                          edits      134
# joshuae                         edits      134
# Wo_Fo                           edits      131
# Mathes                          edits      127
# kathongi                        comments   123
# Hersheysoldier                  edits      119
# wendrock                        edits      119
# Matheo                          edits      118
# Corinna                         reviews    118
# opamp                           edits      117
# lea_b                           edits      114
# Astor                           edits      112
# BaRockA                         edits      109
# hwlang                          edits      107
# tamara_proebster                edits      104
# joshuae                         taxonomy   101
# Anton_Zikmund                   taxonomy    97
# Madlen                          edits       96
# wolfgang                        edits       95
#                                 comments    88
# Menuja                          reviews     87
# Flora_Jana                      reviews     82
#                                 edits       82
# schubertsophia                  taxonomy    82
# lrodriguez                      edits       77
# Pseudo_Informatiker             edits       75
# amankumar1419                   edits       73
# vanessa2021                     edits       63
# Habiba                          taxonomy    60
# Carina_Faude                    edits       59
# Rubikscube                      edits       57
# Menuja                          taxonomy    54
# botho                           edits       52
# LeonieTrautmann                 edits       50
# Max_                            taxonomy    49
# HannaKulke                      taxonomy    49
# LeonieTrautmann                 reviews     48
# Flo123                          edits       47
# Mathes                          taxonomy    47
# ABC19Z                          taxonomy    44
# hxwalther                       reviews     43
# MGoeldner                       edits       43
# Nanami                          taxonomy    43
# gavin                           edits       42
# Flo123                          taxonomy    41
# Theresa_Rudolph                 edits       39
# Rubikscube                      reviews     39
# Menuja                          edits       39
# Annika-Hemlein                  taxonomy    38
# Sharanya                        edits       37
# anne22                          reviews     36
# kdkeller                        edits       35
# schubertsophia                  edits       35
# Vijay                           edits       35
# Kuddelmuddel                    edits       34
# sien-lie                        edits       33
# Tom4Mathe                       edits       33
# Lavanya                         edits       33
# gruenerBogen                    edits       33
# Theresa_Rudolph                 reviews     33
# Kulla                           reviews     32
# kdkeller                        reviews     31
# Kulla                           edits       31
# sivakumar                       edits       30
# Katrin_K                        taxonomy    30
# Efe                             edits       29
# Daniel-Flueck                   edits       29
# jakobwes                        reviews     26
# Vithusha                        edits       25
# randomName23                    edits       25
# AhanaPramanik                   reviews     25
#                                 edits       25
# f_mahn02                        edits       25
# ClaudiaLK                       edits       24
# WandaPaetzold                   comments    24
# Tom4Mathe                       reviews     23
# Marc_Ho                         edits       23
# opamp                           reviews     23
# Mathes                          reviews     22
# Rahuldangi2407                  edits       22
# Albert_Einstein                 edits       22
# Rahuldangi2407                  reviews     22
# Marc_Ho                         reviews     22
# senayildiz                      reviews     21
#                                 edits       21
# Anton_Zikmund                   reviews     20
# Astor                           comments    20
# hwlang                          taxonomy    20
# MaxHerzog                       edits       20
# Madlen                          taxonomy    20
# MaxHerzog                       reviews     20
# Wo_Fo                           taxonomy    20
# lrodriguez                      taxonomy    19
# MelMel                          edits       19
# Elbenjamino                     comments    19
# vanessa2021                     taxonomy    18
# sivakumar                       reviews     18
# anne22                          edits       18
# Renate                          comments    17
# michi_                          reviews     17
# Marc_Ho                         comments    17
# BaRockA                         taxonomy    16
# jakobwes                        edits       16
# Matheo                          reviews     16
# Efe                             taxonomy    15
# SimonDoerig187                  comments    15
# bleacher                        edits       15
# michi_                          edits       15
# wendrock                        comments    15
# Hersheysoldier                  comments    15
# Vijay                           taxonomy    14
# Karin                           comments    14
# NichtsCheckerin                 comments    14
# Mathemachtspa                   comments    14
# Renate                          edits       14
# amankumar1419                   reviews     13
# Adrian_B                        edits       13
# sivakumar                       taxonomy    13
# dal                             comments    13
# Simon                           edits       13
# 16gymnasium_rahden              edits       12
# Renate                          reviews     12
# lea_b                           reviews     12
# 16gymnasium_rahden              reviews     12
# Matheo                          comments    12
# Daniel-Flueck                   comments    12
# ves                             edits       12
# Rebecca_8492                    edits       11
# LukasHuckfeldt                  edits       11
# Louisa_H                        taxonomy    11
# Simon                           reviews     11
# yannikwehr                      comments    11
# tugce                           comments    11
# Wo_Fo                           comments    11
# randomName23                    taxonomy    11
# Daniel-Flueck                   reviews     11
# Kowalsky                        comments    11
# hxwalther                       taxonomy    10
# irlbecksenior                   comments    10
# metzgaria                       comments    10
# sien-lie                        taxonomy    10
# senayildiz                      taxonomy    10
# Hersheysoldier                  taxonomy    10
# Nanami                          comments     9
# lachendesZebra                  taxonomy     9
# Nish                            comments     9
# Flo123                          reviews      9
# acarolinabotelho                edits        9
# wendrock                        taxonomy     9
# 03gymnasium_rahden              edits        8
# Sivani                          edits        8
# gavin                           taxonomy     8
# Peter                           taxonomy     8
# KerstinPecher                   taxonomy     8
# hwlang                          comments     8
# 03gymnasium_rahden              reviews      8
# Kdeegan                         taxonomy     8
# Knorrke                         edits        7
# inyono                          reviews      7
# acarolinabotelho                reviews      7
# Lavanya                         taxonomy     7
# Carina_Faude                    taxonomy     7
# inyono                          edits        7
# lea_b                           taxonomy     7
# gruenerBogen                    reviews      7
# bchij                           edits        7
# BenL                            edits        6
# bleacher                        taxonomy     6
# lachendesZebra                  edits        6
# Kulla                           taxonomy     6
# 13gymnasium_rahden_de           edits        6
# Sharanya                        taxonomy     6
# Kdeegan                         edits        6
# 13gymnasium_rahden_de           reviews      6
# Renate_mit_vielen_Interessen    edits        5
# botho                           comments     5
# 07gymnasium_rahden              edits        5
# Sivani                          taxonomy     5
# Rubikscube                      taxonomy     5
# kakee_in_mathee                 comments     5
# 07gymnasium_rahden              reviews      5
# botho                           reviews      5
# 10gymnasium_rahden              edits        5
#                                 reviews      5
# ClaudiaR                        edits        5
# Nish                            taxonomy     5
# The-Professor                   comments     5
# Vithusha                        reviews      5
#                                 taxonomy     5
# LLu                             comments     5
# bchij                           taxonomy     4
# Pseudo_Informatiker             taxonomy     4
# Injected-Knowledge              comments     4
# neechalkaran                    edits        4
# Kaje                            edits        4
# Nille                           taxonomy     4
# 04gymnasium_rahden              edits        4
# tamara_proebster                taxonomy     4
# testaccount                     edits        4
# Kuddelmuddel                    taxonomy     4
# 04gymnasium_rahden              reviews      4
# anonym_braucht_hilfe            comments     4
# anne22                          taxonomy     4
# Simon                           comments     4
# marwlabs                        edits        3
# Andy                            comments     3
# ClaudiaR                        reviews      3
# 02gymnasium_rahden              edits        3
# TheSwissGuy                     comments     3
# Lorrdiii                        comments     3
# Piero                           taxonomy     3
# Jaantj                          comments     3
# Alex_Lueckenhaus                edits        3
# Kaje                            taxonomy     3
# chi_aaraaa                      comments     3
# Adrian_B                        taxonomy     3
#                                 reviews      3
# eragon1991                      comments     3
# Rebecca_8492                    taxonomy     3
# 21gymnasium-rahden              reviews      3
#                                 edits        3
# 15gymnasium_rahden              reviews      3
#                                 edits        3
# Theresa_Bee                     edits        3
# Mina0105                        comments     3
# AuchNichtAntoniaBllr            comments     3
# Moritz_Rejek                    comments     3
# Theresa_Bee                     reviews      3
# Tharaha                         taxonomy     3
# Eerlu                           comments     3
# beatroot                        comments     3
# 02gymnasium_rahden              reviews      3
# gummo                           comments     3
# peterniz                        comments     3
# BenL                            taxonomy     3
# ClaudiaLK                       reviews      3
# Matheguru                       comments     3
# ves                             comments     3
# hengels                         edits        3
# yannikwehr                      edits        3
# Aurelia-Lilith-Spellmann        comments     3
# Tom4Mathe                       taxonomy     3
# Vater                           comments     2
# Utz                             edits        2
# dck                             comments     2
# Torben                          comments     2
# ast19                           comments     2
# Tom4Mathe                       comments     2
# Teachers_angel                  edits        2
# bastianjoel                     taxonomy     2
# gavin                           reviews      2
# jakobwes                        comments     2
# gruenerBogen                    taxonomy     2
# alropp                          edits        2
# almatho                         comments     2
# Teachers_angel                  taxonomy     2
# alicia435                       comments     2
# SimonDoerig187                  edits        2
# hengels                         taxonomy     2
# jakobwes                        taxonomy     2
# Szohei                          comments     2
# jes04                           comments     2
# Xylocopa                        taxonomy     2
# WarumIstDaEinGleichheitszeichen comments     2
# caly                            comments     2
# Tjark_MS                        edits        2
# 01gymnasium-rahden              edits        2
# Ibeatexpurgations               comments     2
# rooobeert                       comments     2
# travomojo                       comments     2
# prasraph                        comments     2
# Kuddelmuddel                    comments     2
# ClaudiaLK                       taxonomy     2
# Knorrke                         reviews      2
# ralfg1                          edits        2
# randomName23                    comments     2
# Katharina54                     comments     2
# JonathanE                       comments     2
# Corinna                         comments     2
# Digamma                         comments     2
# Leo6969                         comments     2
# schubertsophia                  reviews      2
# 01gymnasium-rahden              reviews      2
# DoLaahnDuc                      comments     2
# Haha_123                        comments     2
# Hadriwa                         comments     2
# Grammhil                        comments     2
# Georg                           comments     2
# sonsonluis                      comments     2
# strarsis                        comments     2
# Eo                              comments     2
# Latzooo                         comments     2
# opamp                           taxonomy     2
# FALSCH123                       comments     2
# williamwilly                    taxonomy     2
# 05gymnasium_rahden              reviews      2
# Aloso                           edits        2
# Maxdddddddd                     comments     2
# mathewurm                       comments     2
# Noah_S                          edits        2
# Andre                           comments     2
# AndrewRobert                    edits        2
# AuchNichtNichtAntonia           comments     2
# NichtAntoniaBllr                comments     2
# 05gymnasium_rahden              edits        2
# Nico_Weio                       edits        2
# Louisa_H                        reviews      2
# Brealin74                       comments     2
# kdkeller                        taxonomy     2
# Albert-zweistein                comments     2
# xXEricIIIXx                     comments     1
# emilia09                        comments     1
# xela2409                        comments     1
# thesupriyasingh                 comments     1
# thegoodking                     comments     1
# testaccount                     taxonomy     1
# williamwilly                    edits        1
# ushamalik                       comments     1
# tinek                           comments     1
# tiserich                        comments     1
# erich                           comments     1
# user21212122                    edits        1
# f_mahn02                        comments     1
# torry                           comments     1
# fh                              comments     1
# vsievybyky                      comments     1
# trdoer                          taxonomy     1
# tamara_proebster                comments     1
# tulpe                           comments     1
# tofkav                          comments     1
# juanitaharter                   comments     1
# swiswa                          comments     1
# gwyneth                         comments     1
# moldt                           comments     1
# michi_                          comments     1
# medyra                          comments     1
# mayu                            comments     1
# marwlabs                        comments     1
# lilly224                        comments     1
# leojohn                         comments     1
# leesadaisy                      comments     1
# krtl                            taxonomy     1
#                                 reviews      1
#                                 edits        1
# janina_reinhardt                taxonomy     1
# krtl                            comments     1
# koehlertim                      edits        1
#                                 comments     1
# dieziegel                       comments     1
# mumbaiescorts23                 comments     1
# nuessa                          edits        1
# sandromarchon                   comments     1
# sunny000sunny                   comments     1
# hannesbk                        comments     1
# stern                           comments     1
# sellmyhousefast                 taxonomy     1
#                                 edits        1
# schreibeLehmann                 comments     1
# herr_schuhuu                    comments     1
# nxndx                           comments     1
# reisedokument67                 comments     1
# qwerty                          comments     1
# qdaffner                        edits        1
# phyks                           taxonomy     1
# p_beutel                        taxonomy     1
# inyono                          taxonomy     1
# dxfne                           comments     1
# Peter-Thomas                    comments     1
# dein_Vater                      comments     1
# Jelle                           comments     1
# JOTIBI                          comments     1
# Isi60                           comments     1
# Ilaria                          comments     1
# Iddly                           comments     1
# HilflosInMathe                  comments     1
# Herr_Paulus                     edits        1
# Hein                            comments     1
# Gerhardus                       comments     1
# GerhardD                        comments     1
# GHn                             edits        1
# FruchtigerTV                    comments     1
# Frederik_Rochell                reviews      1
#                                 edits        1
# Flytzer                         comments     1
# Flying_Angel                    comments     1
# Jacopastorious                  comments     1
# Jidix                           comments     1
# FLOMORIAN                       comments     1
# Jo12345                         comments     1
# Lilla                           taxonomy     1
# LeonieTrautmann                 taxonomy     1
# Leaxaaaa                        comments     1
# Larisa_J                        edits        1
# Lanky                           taxonomy     1
# LWGGRO                          taxonomy     1
# Kyla                            comments     1
# KurtMelnik                      comments     1
# Kulla                           comments     1
# Kopernikus68                    edits        1
# Knorrke                         comments     1
# KerstinPecher                   comments     1
# Katharina54                     taxonomy     1
# Kalli                           comments     1
# JudoKarl                        taxonomy     1
# Flixus                          comments     1
# EvelinaSher                     comments     1
# LordPlumpel                     comments     1
# Backlinksmaker                  comments     1
# BaRockA                         comments     1
# Aurelia-Lilith-Spellmann        edits        1
# Artemia2017                     comments     1
# Antoniabllr                     comments     1
# Alex_Lueckenhaus                reviews      1
# ABC19Z                          comments     1
# 3geometre                       taxonomy     1
# 16gymnasium_rahden              taxonomy     1
# 12gymnasium-rahden              reviews      1
#                                 edits        1
# 11gymnasium_rahdende            reviews      1
#                                 edits        1
# 06gymnasium_rahden              reviews      1
#                                 edits        1
# 04gymnasium_rahden              taxonomy     1
# BaRockA                         reviews      1
# Baothy2211                      comments     1
# Esox                            comments     1
# C0ST                            comments     1
# Erzangel                        comments     1
# Elfriede-200864                 comments     1
# Elbenjamino                     reviews      1
#                                 edits        1
# ElKekso                         edits        1
# Domi2002                        comments     1
# Digamma                         edits        1
# Daniel-Flueck                   taxonomy     1
# Cyberbrat                       comments     1
# ClaudiaR                        taxonomy     1
# Claudia28                       comments     1
# Chembe                          comments     1
# Charlottexxxx                   comments     1
# CarolinJaser                    edits        1
# C_Lipp                          edits        1
# LinkL                           comments     1
# Lufic0or                        taxonomy     1
# danielammann                    comments     1
# Vazmann                         comments     1
# Utz                             comments     1
# Ursula                          comments     1
# Uli90                           comments     1
# Uben                            comments     1
# Tuni                            comments     1
# TrevorM                         comments     1
# Torben                          edits        1
# Tjark_MS                        taxonomy     1
# The-Professor                   edits        1
# Teachers_angel                  comments     1
# Taulant-Osmani                  taxonomy     1
# Tanjoe                          comments     1
# Supremerino                     comments     1
# Stephan91                       comments     1
# StefanR                         comments     1
# Vanesa                          comments     1
# VulpesVulpes                    comments     1
# Sick-Yes                        taxonomy     1
# acarolinabotelho                taxonomy     1
# clarasmith                      comments     1
# chiaraislearning                comments     1
# cherliekevin                    comments     1
# cathleenjone2                   comments     1
# botho                           taxonomy     1
# boss44yt                        comments     1
# bchij                           comments     1
# as_string                       edits        1
# anusaxena                       comments     1
# annacarina                      edits        1
#                                 comments     1
# andre1891                       comments     1
# alropp                          comments     1
# alanvirus                       comments     1
# ahmetkoc001                     edits        1
# Simon                           taxonomy     1
# Sick-Yes                        comments     1
# Lukas_Zapka                     edits        1
# Moritz_Tem                      comments     1
# Mike030                         comments     1
# Mert                            comments     1
# MelMel                          taxonomy     1
#                                 reviews      1
# Me12345                         comments     1
# McCody                          comments     1
# Mathequeen                      taxonomy     1
# Mathemann28737                  comments     1
# Matheistmirlatte                comments     1
# MatheimKopf                     comments     1
# MarK97                          comments     1
# MR                              comments     1
# MAXIEM                          comments     1
# Luna-Zoe                        comments     1
# Lukas_Zapka                     reviews      1
# Mimi_Mia19842007                comments     1
# NNico                           taxonomy     1
# Sely2805                        comments     1
# Nadeen                          taxonomy     1
# Saterael                        comments     1
# Sascha_Lill_95                  comments     1
# Ryker                           comments     1
# Ricford                         comments     1
# Renate_mit_vielen_Interessen    taxonomy     1
#                                 comments     1
# Paul_                           reviews      1
#                                 edits        1
# Palalal                         comments     1
# OrthograFisch                   edits        1
#                                 comments     1
# Ohio1223                        comments     1
# Nogl                            edits        1
# Nauran                          edits        1
# Natan                           edits        1
# zweedorfer                      comments     1
