# %% [markdown]
# # Hilfsfunktionen

# %%
import getpass

API_KEY = getpass.getpass("Simple Analytics API Key: ")
# Out:
# Simple Analytics API Key: ········

# %%
import json
import mysql.connector

from IPython.display import display, Markdown, HTML

db = mysql.connector.connect(
    host="localhost",
    user="root",
    password="secret",
    port="3306",
    database="serlo",
    charset="latin1"
)

def query(sql):
    c = db.cursor()
    c.execute(sql)
    
    return c.fetchall()

def querySingleton(sql):
    return [ x[0] for x in query(sql) ]

def cached(func):
    cache = dict()
    
    def returned_func(*args):
        key = json.dumps(args)
        
        if key not in cache:
            cache[key] = func(*args)
            
        return cache[key]
    
    return returned_func

# %%
@cached
def get_taxonomy_children(taxonomy_id):
    return querySingleton(f"""
        select term_taxonomy.id from term_taxonomy
        join uuid on uuid.id = term_taxonomy.id
        where term_taxonomy.parent_id = {taxonomy_id}
            and uuid.trashed = 0
        order by id
    """)

get_taxonomy_children(16157)
# Out:
# [16158,
#  16159,
#  16160,
#  16161,
#  16162,
#  16163,
#  75049,
#  76750,
#  85477,
#  87814,
#  87827,
#  87860]

# %%
@cached
def get_name(taxonomy_id):
    return querySingleton(f"""
        select term.name from term_taxonomy
        join term on term.id = term_taxonomy.term_id
        where term_taxonomy.id = {taxonomy_id}
    """)[0]

get_name(209228)
# Out:
# 'Aufgaben zu Wertpapieren'

# %%
@cached
def get_entity_children(taxonomy_id):
    return querySingleton(f"""
        select term_taxonomy_entity.entity_id from term_taxonomy
        join term_taxonomy_entity on term_taxonomy_entity.term_taxonomy_id = term_taxonomy.id
        join uuid on uuid.id = term_taxonomy_entity.entity_id
        where term_taxonomy.id = {taxonomy_id}
        and uuid.trashed = 0
        order by term_taxonomy_entity.position
    """)

get_entity_children(16174)
# Out:
# [2111,
#  18685,
#  1717,
#  1993,
#  107488,
#  107903,
#  121533,
#  121535,
#  129709,
#  19336,
#  1525,
#  1677,
#  1495,
#  1871,
#  2153,
#  1507,
#  1639,
#  1633,
#  1679,
#  1671]

# %%
import requests
import time

@cached
def get_alias(uuid_id, attempt=0):
    req = requests.get(f"https://de.serlo.org/{uuid_id}", allow_redirects=False)
    
    if "Location" not in req.headers:
        if attempt <= 2:
            time.sleep(5)
            return get_alias(uuid_id, attempt = attempt+1)
        else:
            return None
    else:
        return req.headers["Location"][len("https://de.serlo.org"):]
    
get_alias(16174)
# Out:
# '/mathe/16174/grundrechenarten-und-rechengesetze'

# %%
@cached
def get_page_views(uuid_id):
    alias = get_alias(uuid_id)
    
    if alias == None:
        return {"pageviews": 0, "visitors": 0}
    
    req = requests.get("https://simpleanalytics.com/de.serlo.org.json", params={
        "version": "5",
        "fields": "pageviews,visitors",
        "page": alias
    }, headers = {
        "Content-Type": "json",
        "Api-Key": API_KEY
    })
    
    return req.json()

get_page_views(16174)
# Out:
# {'__ok': 'INFO: With this boolean you can quickly check if you can expect a response',
#  'ok': True,
#  'docs': 'https://docs.simpleanalytics.com/api',
#  '__info': "INFO: Disable these info fields by adding 'info=false' to the URL.",
#  'info': True,
#  'hostname': 'de.serlo.org',
#  'url': 'https://de.serlo.org',
#  '__path': 'INFO: You are using a path in the URLcounts are relative to only that path.',
#  'path': '/mathe/16174/grundrechenarten-und-rechengesetze',
#  'start': '2021-06-13T22:00:00.000Z',
#  'end': '2021-07-14T22:59:59.999Z',
#  '__version': "INFO: API version. You are using the latest version. You can specify versions by added 'version=5' to your URL (valid versions: 1, 2, 3, 4, 5)",
#  'version': 5,
#  '__timezone': 'INFO: You can change your timezone in your website settings',
#  'timezone': 'Europe/Berlin',
#  '__pageviews': 'INFO: Just a total of all pageviews',
#  'pageviews': 10,
#  '__visitors': 'INFO: Just a total of all visitors',
#  'visitors': 7,
#  '__generated_in_ms': 'INFO: Time needed to generate this response on the server in milliseconds',
#  'generated_in_ms': 532}

# %%
def iter_all_uuids(taxonomy_id):
    yield taxonomy_id
    yield from get_entity_children(taxonomy_id)
    
    for child in get_taxonomy_children(taxonomy_id):
        yield from iter_all_uuids(child)
    
list(iter_all_uuids(175157))
# Out:
# [175157,
#  16174,
#  2111,
#  18685,
#  1717,
#  1993,
#  107488,
#  107903,
#  121533,
#  121535,
#  129709,
#  19336,
#  1525,
#  1677,
#  1495,
#  1871,
#  2153,
#  1507,
#  1639,
#  1633,
#  1679,
#  1671,
#  21804,
#  9189,
#  9145,
#  4181,
#  4185,
#  6607,
#  6491,
#  9161,
#  9165,
#  9173,
#  9149,
#  6857,
#  6861,
#  6865,
#  6877,
#  2217,
#  7331,
#  6881,
#  6873,
#  207224,
#  209278,
#  209282,
#  209288,
#  209337,
#  218600,
#  22251,
#  9741,
#  9549,
#  9757,
#  9743,
#  9563,
#  9157,
#  9153,
#  120853,
#  120854,
#  120860,
#  208844,
#  209276,
#  22257,
#  9627,
#  13651,
#  9641,
#  10613,
#  22258,
#  9513,
#  9045,
#  6593,
#  6487,
#  10771,
#  4969,
#  6929,
#  10543,
#  10719,
#  10775,
#  4973,
#  10039,
#  120847,
#  121178,
#  121192,
#  209656,
#  209685,
#  40879,
#  4347,
#  4349,
#  6837,
#  6813,
#  7157,
#  10323,
#  8697,
#  6833,
#  6829,
#  6825,
#  6821,
#  6817,
#  175163,
#  175166,
#  175167]

# %%
@cached
def get_total(taxonomy_id):
    uuids = set(iter_all_uuids(taxonomy_id))
    views = [get_page_views(uuid_id) for uuid_id in uuids]
    
    return {
        "pageviews": sum([x["pageviews"] for x in views]),
        "visitors": sum([x["visitors"] for x in views]),
    }

get_total(175157)
# Out:
# {'pageviews': 4712, 'visitors': 2705}

# %% [markdown]
# # Auswertung

# %%
def show(taxonomy_id, max_depth=2, depth=0):
    line = ""
    
    if depth > 0:
        line += "  " * depth
        line += "|- "
        
    line += get_name(taxonomy_id)
    line += ": "
    
    total = get_total(taxonomy_id)
    
    line += str({
        "pageviews": total["pageviews"],
        "visitors": total["visitors"]
    })
    
    print(line)
    
    if depth <= max_depth:
        for child in get_taxonomy_children(taxonomy_id):
            show(child, depth=depth+1, max_depth=max_depth)
    
    
show(16157)
show(16259)
# Out:
# Realschule: {'pageviews': 210894, 'visitors': 166167}
#   |- Klasse 5: {'pageviews': 25573, 'visitors': 19903}
#     |- Ganze Zahlen: {'pageviews': 16, 'visitors': 0}
#     |- GrÃ¶Ãen: {'pageviews': 10155, 'visitors': 9446}
#       |- Aufgaben zu GrÃ¶Ãen und Einheiten: {'pageviews': 9, 'visitors': 0}
#     |- Auswertung von Daten: {'pageviews': 148, 'visitors': 60}
#       |- Aufgaben zu Daten und Zufallsexperimente: {'pageviews': 5, 'visitors': 1}
#     |- Geometrische Grundvorstellungen und Grundbegriffe: {'pageviews': 9039, 'visitors': 6503}
#       |- Aufgaben zu geometrischen Grundformen und Grundbegriffen: {'pageviews': 15, 'visitors': 0}
#     |- Umfang und FlÃ¤cheninhalt ebener Figuren: {'pageviews': 4440, 'visitors': 3386}
#     |- NatÃ¼rliche Zahlen: {'pageviews': 4712, 'visitors': 2705}
#       |- Grundrechenarten und Rechengesetze: {'pageviews': 4617, 'visitors': 2705}
#       |- NatÃ¼rliche Zahlen im Dezimalsystem: {'pageviews': 13, 'visitors': 0}
#       |- Andere Zahlsysteme: {'pageviews': 3, 'visitors': 0}
#       |- Kombinatorik: {'pageviews': 1, 'visitors': 0}
#   |- Klasse 6: {'pageviews': 21455, 'visitors': 15471}
#     |- Positive rationale Zahlen: {'pageviews': 5779, 'visitors': 4299}
#       |- Aufgaben zum Erweitern und KÃ¼rzen: {'pageviews': 7, 'visitors': 1}
#       |- Aufgaben zum Ordnen von BrÃ¼chen: {'pageviews': 0, 'visitors': 0}
#       |- Aufgaben zum BruchverstÃ¤ndnis: {'pageviews': 1, 'visitors': 1}
#       |- Aufgaben zu den Grundrechenarten mit BrÃ¼chen: {'pageviews': 2, 'visitors': 0}
#       |- Sachaufgaben zu BrÃ¼chen: {'pageviews': 22, 'visitors': 19}
#     |- DezimalbrÃ¼che: {'pageviews': 3555, 'visitors': 3118}
#       |- Aufgaben zu den Grundrechenarten mit DezimalbrÃ¼chen: {'pageviews': 18, 'visitors': 8}
#       |- Aufgaben zum Umwandeln von BrÃ¼chen und DezimalbrÃ¼chen: {'pageviews': 6, 'visitors': 1}
#       |- Aufgaben zum Vergleichen von DezimalbrÃ¼chen: {'pageviews': 0, 'visitors': 0}
#       |- Aufgaben zum Runden : {'pageviews': 20, 'visitors': 18}
#       |- Aufgaben zur Stellenwerttafel: {'pageviews': 0, 'visitors': 0}
#       |- Gemischte Aufgaben zu BrÃ¼chen und Dezimalzahlen: {'pageviews': 1, 'visitors': 0}
#     |- Gleichungen und Ungleichungen : {'pageviews': 3245, 'visitors': 1507}
#       |- Aufgaben zum Belegen von Termen: {'pageviews': 8, 'visitors': 1}
#       |- Aufgaben zum Aufstellen von Termen: {'pageviews': 33, 'visitors': 22}
#       |- Aufgaben zu Termumformungen: {'pageviews': 79, 'visitors': 58}
#       |- Aufgaben zum LÃ¶sen von Sachaufgaben mit x-Ansatz: {'pageviews': 73, 'visitors': 63}
#       |- Aufgaben zu linearen Ungleichungen: {'pageviews': 1, 'visitors': 1}
#       |- Sachaufgaben zu linearen Ungleichungen: {'pageviews': 6, 'visitors': 5}
#       |- Aufgaben zu Gleichungen: {'pageviews': 2, 'visitors': 0}
#     |- Direkte ProportionalitÃ¤t: {'pageviews': 1987, 'visitors': 1449}
#       |- Aufgaben zur direkten ProportionalitÃ¤t: {'pageviews': 29, 'visitors': 14}
#     |- Grundbegriffe Geometrie: {'pageviews': 6756, 'visitors': 5029}
#     |- Achsenspiegelung: {'pageviews': 7, 'visitors': 0}
#     |- Daten und Zufallsexperimente: {'pageviews': 6, 'visitors': 0}
#     |- Raummessung: {'pageviews': 107, 'visitors': 67}
#       |- Aufgaben zur Raummessung: {'pageviews': 49, 'visitors': 25}
#   |- Klasse 7: {'pageviews': 25316, 'visitors': 18411}
#     |- Zweig I: {'pageviews': 24252, 'visitors': 17745}
#       |- Rationale Zahlen : {'pageviews': 2314, 'visitors': 1527}
#       |- Gleichungen und Ungleichungen : {'pageviews': 665, 'visitors': 128}
#       |- ProportionalitÃ¤ten und Prozentrechnen: {'pageviews': 2382, 'visitors': 1778}
#       |- Parallelverschiebung: {'pageviews': 8041, 'visitors': 6753}
#       |- Drehung: {'pageviews': 452, 'visitors': 404}
#       |- Daten und Zufallsexperimente: {'pageviews': 1903, 'visitors': 1506}
#       |- Geometrische Ortslinien und Ortsbereiche: {'pageviews': 716, 'visitors': 392}
#       |- Lehrplan Plus: {'pageviews': 18318, 'visitors': 13661}
#     |- Zweig II und III: {'pageviews': 17772, 'visitors': 12908}
#       |- Rationale Zahlen : {'pageviews': 3357, 'visitors': 2035}
#       |- Gleichungen und Ungleichungen : {'pageviews': 2768, 'visitors': 1212}
#       |- ProportionalitÃ¤ten und Prozentrechnen: {'pageviews': 1901, 'visitors': 1561}
#       |- Parallelverschiebung und Vektoren: {'pageviews': 7523, 'visitors': 6304}
#       |- Drehung: {'pageviews': 453, 'visitors': 404}
#       |- Daten und Zufallsexperimente: {'pageviews': 1698, 'visitors': 1390}
#       |- Lehrplan Plus: {'pageviews': 3, 'visitors': 0}
#   |- Klasse 8: {'pageviews': 56091, 'visitors': 44967}
#     |- Zweig I: {'pageviews': 51731, 'visitors': 41666}
#       |- Terme, Gleichungen und Ungleichungen: {'pageviews': 12563, 'visitors': 9479}
#       |- Bruchterme und Bruchgleichungen: {'pageviews': 1624, 'visitors': 1215}
#       |- Funktionen: {'pageviews': 22197, 'visitors': 18989}
#       |- Vierecke: {'pageviews': 5847, 'visitors': 4425}
#       |- Raumgeometrie: {'pageviews': 2328, 'visitors': 2053}
#       |- Daten und Zufall: {'pageviews': 6972, 'visitors': 5443}
#       |- Drehung: {'pageviews': 82, 'visitors': 59}
#     |- Zweig II und III: {'pageviews': 47170, 'visitors': 37711}
#       |- Terme und Gleichungen: {'pageviews': 11940, 'visitors': 8940}
#       |- Bruchterme und Bruchgleichungen: {'pageviews': 1928, 'visitors': 1491}
#       |- Dreiecke und Vierecke: {'pageviews': 7710, 'visitors': 5776}
#       |- Daten und Zufall: {'pageviews': 5555, 'visitors': 4268}
#       |- Raumgeometrie: {'pageviews': 413, 'visitors': 365}
#       |- Funktionen: {'pageviews': 19494, 'visitors': 16867}
#   |- Klasse 9: {'pageviews': 64163, 'visitors': 51721}
#     |- Zweig I: {'pageviews': 56595, 'visitors': 46141}
#       |- Systeme linearer Gleichungen: {'pageviews': 754, 'visitors': 207}
#       |- Reelle Zahlen: {'pageviews': 1942, 'visitors': 1437}
#       |- Quadratische Funktionen: {'pageviews': 8389, 'visitors': 6630}
#       |- Quadratische Gleichungen und Ungleichungen: {'pageviews': 5844, 'visitors': 4347}
#       |- Systeme mit quadratischen Gleichungen: {'pageviews': 627, 'visitors': 536}
#       |- FlÃ¤cheninhalt von Figuren: {'pageviews': 3853, 'visitors': 2897}
#       |- Zentrische Streckung: {'pageviews': 5032, 'visitors': 4620}
#       |- Satzgruppe des Pythagoras - FlÃ¤chensÃ¤tze: {'pageviews': 9220, 'visitors': 7967}
#       |- Berechnungen am Kreis: {'pageviews': 16766, 'visitors': 15133}
#       |- Raumgeomtrie: {'pageviews': 3558, 'visitors': 2520}
#       |- Daten und Zufallsexperimente: {'pageviews': 4349, 'visitors': 3472}
#     |- Zweig II und III: {'pageviews': 25639, 'visitors': 20023}
#       |- Funktionen: {'pageviews': 3739, 'visitors': 2850}
#       |- Lineare Funktionen: {'pageviews': 3421, 'visitors': 2667}
#       |- Systeme linearer Gleichungen: {'pageviews': 750, 'visitors': 207}
#       |- Reelle Zahlen: {'pageviews': 1939, 'visitors': 1438}
#       |- Zentrische Streckung: {'pageviews': 5017, 'visitors': 4613}
#       |- Satzgruppe des Pythagoras - FlÃ¤chensÃ¤tze: {'pageviews': 9274, 'visitors': 7981}
#       |- Raumgeometrie: {'pageviews': 77, 'visitors': 23}
#       |- Daten und Zufallsexperimente: {'pageviews': 1254, 'visitors': 966}
#       |- FlÃ¤cheninhalt von Figuren: {'pageviews': 3858, 'visitors': 2898}
#   |- Klasse 10: {'pageviews': 91995, 'visitors': 77318}
#     |- Zweig I: {'pageviews': 43710, 'visitors': 37032}
#       |- Potenzen und Potenzfunktionen: {'pageviews': 2500, 'visitors': 1585}
#       |- Exponential- und Logarithmusfunktionen: {'pageviews': 7402, 'visitors': 6058}
#       |- Trigonometrie: {'pageviews': 32597, 'visitors': 28537}
#       |- Abbildungen im Koordinatensystem: {'pageviews': 1039, 'visitors': 839}
#     |- Zweig II und III: {'pageviews': 76716, 'visitors': 65141}
#       |- Quadratische Funktionen: {'pageviews': 8984, 'visitors': 7168}
#       |- Funktionen der indirekten ProportionalitÃ¤t und Exponentialfunktion: {'pageviews': 3522, 'visitors': 2694}
#       |- Quadratische Gleichungen: {'pageviews': 17453, 'visitors': 14548}
#       |- Berechnungen am Kreis: {'pageviews': 16737, 'visitors': 15081}
#       |- Raumgeometrie: {'pageviews': 3287, 'visitors': 2282}
#       |- Trigonometrie: {'pageviews': 26552, 'visitors': 23356}
#       |- Auf einen Blick: {'pageviews': 2, 'visitors': 0}
#   |- AbschlussprÃ¼fungen mit LÃ¶sung, Zweig I: {'pageviews': 2550, 'visitors': 588}
#     |- 2015: {'pageviews': 125, 'visitors': 17}
#       |- Teil A: {'pageviews': 36, 'visitors': 6}
#       |- Teil B: {'pageviews': 41, 'visitors': 8}
#     |- 2016: {'pageviews': 244, 'visitors': 62}
#       |- Teil A: {'pageviews': 46, 'visitors': 6}
#       |- Teil B: {'pageviews': 48, 'visitors': 17}
#       |- Nachtermin Teil A: {'pageviews': 45, 'visitors': 14}
#       |- Nachtermin Teil B: {'pageviews': 27, 'visitors': 5}
#     |- 2017: {'pageviews': 352, 'visitors': 109}
#       |- Teil A: {'pageviews': 77, 'visitors': 23}
#       |- Teil B: {'pageviews': 71, 'visitors': 3}
#       |- Nachtermin Teil A: {'pageviews': 107, 'visitors': 54}
#       |- Nachtermin Teil B: {'pageviews': 26, 'visitors': 6}
#     |- 2018: {'pageviews': 202, 'visitors': 21}
#       |- Teil A: {'pageviews': 47, 'visitors': 5}
#       |- Teil B: {'pageviews': 47, 'visitors': 9}
#       |- Nachtermin Teil A: {'pageviews': 21, 'visitors': 3}
#       |- Nachtermin Teil B: {'pageviews': 33, 'visitors': 4}
#     |- 2019: {'pageviews': 251, 'visitors': 32}
#       |- Teil A: {'pageviews': 62, 'visitors': 9}
#       |- Teil B: {'pageviews': 46, 'visitors': 6}
#       |- Nachtermin Teil A: {'pageviews': 41, 'visitors': 9}
#       |- Nachtermin Teil B: {'pageviews': 25, 'visitors': 4}
#     |- 2020: {'pageviews': 532, 'visitors': 30}
#       |- Teil A: {'pageviews': 168, 'visitors': 15}
#       |- Teil B: {'pageviews': 91, 'visitors': 5}
#       |- Nachtermin Teil A: {'pageviews': 23, 'visitors': 2}
#       |- Nachtermin Teil B: {'pageviews': 53, 'visitors': 6}
#   |- AbschlussprÃ¼fungen mit LÃ¶sungen, Zweig II und III: {'pageviews': 2256, 'visitors': 508}
#     |- 2016: {'pageviews': 227, 'visitors': 45}
#       |- Teil A: {'pageviews': 51, 'visitors': 10}
#       |- Teil B: {'pageviews': 72, 'visitors': 15}
#       |- Nachtermin Teil A: {'pageviews': 31, 'visitors': 14}
#       |- Nachtermin Teil B: {'pageviews': 35, 'visitors': 3}
#     |- 2015: {'pageviews': 80, 'visitors': 7}
#       |- Teil A: {'pageviews': 23, 'visitors': 1}
#       |- Teil B: {'pageviews': 17, 'visitors': 5}
#       |- Nachtermin Teil A: {'pageviews': 5, 'visitors': 1}
#       |- Nachtermin Teil B: {'pageviews': 6, 'visitors': 0}
#     |- 2017: {'pageviews': 167, 'visitors': 18}
#       |- Teil A: {'pageviews': 38, 'visitors': 2}
#       |- Teil B: {'pageviews': 59, 'visitors': 15}
#       |- Nachtermin Teil A: {'pageviews': 12, 'visitors': 0}
#       |- Nachtermin Teil B: {'pageviews': 9, 'visitors': 0}
#     |- 2018: {'pageviews': 291, 'visitors': 54}
#       |- Teil A: {'pageviews': 44, 'visitors': 7}
#       |- Teil B: {'pageviews': 81, 'visitors': 18}
#       |- Nachtermin Teil A: {'pageviews': 30, 'visitors': 8}
#       |- Nachtermin Teil B: {'pageviews': 78, 'visitors': 20}
#     |- 2019: {'pageviews': 261, 'visitors': 23}
#       |- Teil A: {'pageviews': 58, 'visitors': 5}
#       |- Teil B: {'pageviews': 54, 'visitors': 8}
#       |- Nachtermin Teil A: {'pageviews': 32, 'visitors': 7}
#       |- Nachtermin Teil B: {'pageviews': 19, 'visitors': 1}
#     |- 2020: {'pageviews': 412, 'visitors': 26}
#       |- Teil A: {'pageviews': 141, 'visitors': 10}
#       |- Teil B: {'pageviews': 94, 'visitors': 1}
#       |- Nachtermin Teil A: {'pageviews': 27, 'visitors': 4}
#       |- Nachtermin Teil B: {'pageviews': 31, 'visitors': 11}
#   |- Jahrgangsstufentest 8. Klasse: {'pageviews': 218, 'visitors': 21}
#     |- 2017: {'pageviews': 4, 'visitors': 0}
#       |- Zweig II und III: {'pageviews': 2, 'visitors': 0}
#       |- Zweig I: {'pageviews': 2, 'visitors': 0}
#     |- 2016: {'pageviews': 18, 'visitors': 8}
#       |- Zweig II und III: {'pageviews': 9, 'visitors': 7}
#       |- Zweig I: {'pageviews': 11, 'visitors': 8}
#     |- 2018: {'pageviews': 16, 'visitors': 7}
#       |- Zweig I: {'pageviews': 8, 'visitors': 7}
#       |- Zweig II+III: {'pageviews': 5, 'visitors': 0}
#     |- 2019: {'pageviews': 49, 'visitors': 6}
#       |- Zweig I: {'pageviews': 21, 'visitors': 3}
#       |- Zweig II+III: {'pageviews': 6, 'visitors': 3}
#     |- 2020: {'pageviews': 97, 'visitors': 0}
#       |- Zweig I: {'pageviews': 31, 'visitors': 0}
#       |- Zeil II und III: {'pageviews': 18, 'visitors': 0}
#   |- Jahrgangsstufentest 6. Klasse: {'pageviews': 322, 'visitors': 40}
#     |- 2016: {'pageviews': 3, 'visitors': 0}
#     |- 2017: {'pageviews': 18, 'visitors': 14}
#     |- 2015: {'pageviews': 12, 'visitors': 6}
#     |- 2018: {'pageviews': 17, 'visitors': 5}
#     |- 2019: {'pageviews': 44, 'visitors': 6}
#     |- 2020: {'pageviews': 133, 'visitors': 7}
#   |- Grundwissentest 7. Klasse: {'pageviews': 134, 'visitors': 10}
#     |- 2017: {'pageviews': 15, 'visitors': 3}
#     |- 2016: {'pageviews': 3, 'visitors': 1}
#     |- 2018: {'pageviews': 9, 'visitors': 0}
#     |- 2019: {'pageviews': 10, 'visitors': 1}
#     |- 2020: {'pageviews': 33, 'visitors': 0}
#   |- Grundwissentest 9. Klasse: {'pageviews': 282, 'visitors': 13}
#     |- 2017: {'pageviews': 44, 'visitors': 4}
#       |- Zweig I: {'pageviews': 21, 'visitors': 2}
#       |- Zweig II und III: {'pageviews': 6, 'visitors': 4}
#     |- 2016: {'pageviews': 10, 'visitors': 4}
#       |- Zweig II und III: {'pageviews': 5, 'visitors': 4}
#       |- Zweig I: {'pageviews': 1, 'visitors': 0}
#     |- 2018: {'pageviews': 21, 'visitors': 0}
#       |- Zweig I: {'pageviews': 7, 'visitors': 0}
#       |- Zweig II +III: {'pageviews': 4, 'visitors': 0}
#     |- 2019: {'pageviews': 34, 'visitors': 1}
#       |- Zweig I: {'pageviews': 14, 'visitors': 0}
#       |- Zweig II und III: {'pageviews': 6, 'visitors': 0}
#     |- 2020: {'pageviews': 103, 'visitors': 0}
#       |- Zweig I: {'pageviews': 42, 'visitors': 0}
#       |- Zweig II + III: {'pageviews': 22, 'visitors': 0}
# Mittelschule: {'pageviews': 213785, 'visitors': 97801}
#   |- Klasse 5: {'pageviews': 1561, 'visitors': 708}
#     |- NatÃ¼rliche Zahlen: {'pageviews': 345, 'visitors': 4}
#       |- Grundrechenarten im Bereich der natÃ¼rlichen Zahlen: {'pageviews': 87, 'visitors': 4}
#       |- Der Zahlenraum Ã¼ber eine Milliarde hinaus: {'pageviews': 91, 'visitors': 0}
#     |- Gleichungen und Formeln: {'pageviews': 95, 'visitors': 1}
#       |- Aufgaben zu Termen und Gleichungen: {'pageviews': 33, 'visitors': 1}
#     |- Ganze Zahlen: {'pageviews': 82, 'visitors': 30}
#       |- Aufgaben zu Zahlenstrahl und Zahlengerade: {'pageviews': 17, 'visitors': 13}
#       |- Aufgaben zur Addition und Subtraktion ganzer Zahlen: {'pageviews': 10, 'visitors': 6}
#       |- Sachaufgaben zu ganzen Zahlen: {'pageviews': 10, 'visitors': 7}
#       |- Aufgaben zum GrÃ¶Ãenvergeich ganzer Zahlen: {'pageviews': 8, 'visitors': 2}
#     |- GrÃ¶Ãen im Alltag: {'pageviews': 34, 'visitors': 0}
#     |- Geometrische Figuren und Lagebeziehungen: {'pageviews': 52, 'visitors': 4}
#     |- FlÃ¤cheninhalt - Rechtecke: {'pageviews': 901, 'visitors': 668}
#       |- Aufgaben zum Thema Rechnen mit LÃ¤ngeneinheiten: {'pageviews': 28, 'visitors': 16}
#       |- Aufgaben zum Umfang und FlÃ¤cheninhalt von Quadrat und Rechteck: {'pageviews': 722, 'visitors': 643}
#       |- Aufgaben zum Rechnen mit FlÃ¤cheneinheiten: {'pageviews': 40, 'visitors': 5}
#     |- Daten: {'pageviews': 10, 'visitors': 0}
#   |- Klasse 6: {'pageviews': 2191, 'visitors': 1361}
#     |- Rationale Zahlen : {'pageviews': 110, 'visitors': 17}
#       |- Erweiterung des Zahlbereichs auf rationale Zahlen: {'pageviews': 5, 'visitors': 0}
#       |- Grundrechenarten im Bereich der rationalen Zahlen: {'pageviews': 59, 'visitors': 14}
#     |- Geometrische Figuren, KÃ¶rper und Lagebeziehungen: {'pageviews': 62, 'visitors': 4}
#       |- Aufgaben zu Vierecken: {'pageviews': 21, 'visitors': 2}
#     |- FlÃ¤cheninhalt - OberflÃ¤cheninhalt von Quadern: {'pageviews': 1522, 'visitors': 1253}
#       |- Aufgaben zu OberflÃ¤che und Volumen von WÃ¼rfel und Quader: {'pageviews': 1455, 'visitors': 1247}
#     |- Gleichungen und Formeln: {'pageviews': 192, 'visitors': 66}
#       |- Aufgaben zum Einsetzen in Terme: {'pageviews': 30, 'visitors': 14}
#       |- Aufgaben zum Aufstellen von Termen: {'pageviews': 7, 'visitors': 3}
#       |- Aufgaben zum Umformen von Termen: {'pageviews': 11, 'visitors': 0}
#       |- Sachaufgaben zu Gleichungen: {'pageviews': 63, 'visitors': 46}
#       |- Aufgaben zu linearen Gleichungen: {'pageviews': 25, 'visitors': 2}
#     |- Bruchzahlen: {'pageviews': 267, 'visitors': 21}
#       |- Erweiterung des Zahlbereichs auf Bruchzahlen: {'pageviews': 88, 'visitors': 3}
#       |- Rechnen mit Bruchzahlen: {'pageviews': 45, 'visitors': 0}
#     |- Rauminhalt - Quader: {'pageviews': 9, 'visitors': 0}
#     |- Daten: {'pageviews': 7, 'visitors': 0}
#   |- Klasse 7: {'pageviews': 915, 'visitors': 360}
#     |- Regelklasse: {'pageviews': 225, 'visitors': 9}
#       |- Rationale Zahlen - Rechenregeln: {'pageviews': 40, 'visitors': 6}
#       |- Prozentrechnung: {'pageviews': 4, 'visitors': 0}
#       |- Geometrische Figuren, KÃ¶rper und Lagebeziehungen: {'pageviews': 20, 'visitors': 1}
#       |- FlÃ¤cheninhalte - Parallelogramme und Dreiecke: {'pageviews': 10, 'visitors': 0}
#       |- Rauminhalt - gerade Prismen: {'pageviews': 3, 'visitors': 0}
#       |- Diagramme und statistische Kennwerte: {'pageviews': 5, 'visitors': 1}
#       |- Gleichungen: {'pageviews': 9, 'visitors': 0}
#       |- ProportionalitÃ¤t: {'pageviews': 9, 'visitors': 0}
#     |- M-Klasse: {'pageviews': 671, 'visitors': 354}
#       |- Prozentrechnung: {'pageviews': 404, 'visitors': 251}
#       |- FlÃ¤cheninhalte - Parallelogramme und Dreiecke: {'pageviews': 4, 'visitors': 0}
#       |- Rauminhalt - gerade Prismen: {'pageviews': 10, 'visitors': 1}
#       |- Gleichungen: {'pageviews': 14, 'visitors': 0}
#       |- Rationale Zahlen - Rechenregeln: {'pageviews': 23, 'visitors': 5}
#       |- ProportionalitÃ¤t: {'pageviews': 119, 'visitors': 97}
#       |- Geometrische Figuren, KÃ¶rper und Lagebeziehungen: {'pageviews': 4, 'visitors': 0}
#       |- Diagramme und statistische Kennwerte: {'pageviews': 1, 'visitors': 0}
#   |- Klasse 8: {'pageviews': 70996, 'visitors': 58971}
#     |- Regelklasse: {'pageviews': 61261, 'visitors': 50443}
#       |- Prozentrechnung: {'pageviews': 28285, 'visitors': 24228}
#       |- Quadratzahlen und Quadratwurzeln: {'pageviews': 828, 'visitors': 459}
#       |- Geometrische Figuren, KÃ¶rper und Lagebeziehungen: {'pageviews': 68, 'visitors': 39}
#       |- FlÃ¤cheninhalt - Kreise: {'pageviews': 15752, 'visitors': 14218}
#       |- Rauminhalt - Zylinder: {'pageviews': 1941, 'visitors': 1491}
#       |- Zufallsexperimente: {'pageviews': 7441, 'visitors': 6016}
#       |- Gleichungen: {'pageviews': 3446, 'visitors': 1713}
#       |- Funktionale ZusammenhÃ¤nge : {'pageviews': 3247, 'visitors': 2273}
#     |- M-Klasse: {'pageviews': 70474, 'visitors': 58869}
#       |- Prozentrechnung: {'pageviews': 28274, 'visitors': 24252}
#       |- Gleichungen: {'pageviews': 3410, 'visitors': 1709}
#       |- Funktionale ZusammenhÃ¤nge : {'pageviews': 11897, 'visitors': 10055}
#       |- FlÃ¤cheninhalt - Kreise: {'pageviews': 16353, 'visitors': 14720}
#       |- Rauminhalt - Zylinder: {'pageviews': 1978, 'visitors': 1525}
#       |- Quadratzahlen und Quadratwurzeln: {'pageviews': 832, 'visitors': 471}
#       |- Geometrische Figuren, KÃ¶rper und Lagebeziehungen: {'pageviews': 127, 'visitors': 102}
#       |- Zufallsexperimente: {'pageviews': 7466, 'visitors': 6025}
#   |- Klasse 9: {'pageviews': 20973, 'visitors': 13947}
#     |- Prozent- und Zinsrechnung: {'pageviews': 1960, 'visitors': 962}
#       |- Aufgaben zu vermehrtem und vermindertem Grundwert: {'pageviews': 309, 'visitors': 212}
#       |- Aufgaben zur Zinsrechnung: {'pageviews': 173, 'visitors': 125}
#     |- Potenzen und Wurzeln: {'pageviews': 814, 'visitors': 372}
#       |- Aufgaben zu Quadratwurzeln: {'pageviews': 18, 'visitors': 1}
#       |- Aufgaben zu einfachen Potenzen: {'pageviews': 13, 'visitors': 1}
#       |- Aufgaben zu Potenzen mit ganzzahligen Exponenten: {'pageviews': 8, 'visitors': 0}
#     |- Geometrie: {'pageviews': 9233, 'visitors': 6847}
#       |- Geometrische FlÃ¤chen und geometrisches Zeichnen: {'pageviews': 6529, 'visitors': 5276}
#       |- Geometrische KÃ¶rper: {'pageviews': 2429, 'visitors': 1551}
#     |- Gleichungen und Formeln: {'pageviews': 2515, 'visitors': 874}
#       |- Aufgaben zu Gleichungen: {'pageviews': 615, 'visitors': 499}
#       |- Aufgaben zum LÃ¶sen von Sachaufgaben mit x-Ansatz: {'pageviews': 121, 'visitors': 81}
#     |- Funktionen: {'pageviews': 983, 'visitors': 485}
#       |- Aufgaben zu linearen Funktionen : {'pageviews': 62, 'visitors': 41}
#     |- Statistik: {'pageviews': 5269, 'visitors': 4378}
#       |- Aufgaben zu Diagrammen: {'pageviews': 29, 'visitors': 19}
#       |- Aufgaben zum Median: {'pageviews': 131, 'visitors': 124}
#       |- Aufgaben zum arithmetischen Mittel: {'pageviews': 19, 'visitors': 5}
#   |- Quali AbschlussprÃ¼fungen mit LÃ¶sung: {'pageviews': 118504, 'visitors': 27188}
#     |- 2016: {'pageviews': 5532, 'visitors': 497}
#       |- Teil A: {'pageviews': 1368, 'visitors': 102}
#       |- Teil B, Gruppe 1: {'pageviews': 1398, 'visitors': 112}
#       |- Teil B, Gruppe 2: {'pageviews': 1141, 'visitors': 106}
#       |- Teil B, Gruppe 3: {'pageviews': 874, 'visitors': 89}
#     |- 2015: {'pageviews': 6523, 'visitors': 621}
#       |- Teil A: {'pageviews': 1864, 'visitors': 134}
#       |- Teil B, Gruppe 1: {'pageviews': 1542, 'visitors': 139}
#       |- Teil B, Gruppe 2: {'pageviews': 1151, 'visitors': 96}
#       |- Teil B, Gruppe 3: {'pageviews': 981, 'visitors': 126}
#     |- 2017: {'pageviews': 6708, 'visitors': 804}
#       |- Teil A: {'pageviews': 2035, 'visitors': 255}
#       |- Teil B, Gruppe 1: {'pageviews': 1446, 'visitors': 110}
#       |- Teil B, Gruppe 2: {'pageviews': 1143, 'visitors': 145}
#       |- Teil B, Gruppe 3: {'pageviews': 1087, 'visitors': 170}
#     |- 2018: {'pageviews': 7971, 'visitors': 905}
#       |- Teil A: {'pageviews': 2319, 'visitors': 238}
#       |- Teil B, Gruppe 1: {'pageviews': 1930, 'visitors': 198}
#       |- Teil B, Gruppe 2: {'pageviews': 1402, 'visitors': 159}
#       |- Teil B, Gruppe 3: {'pageviews': 1251, 'visitors': 167}
#     |- 2019: {'pageviews': 10777, 'visitors': 1069}
#       |- Teil A: {'pageviews': 3570, 'visitors': 469}
#       |- Teil B, Gruppe 1: {'pageviews': 2544, 'visitors': 177}
#       |- Teil B, Gruppe 2: {'pageviews': 1694, 'visitors': 96}
#       |- Teil B, Gruppe 3: {'pageviews': 1449, 'visitors': 125}
#     |- 2020: {'pageviews': 26203, 'visitors': 1986}
#       |- Teil A: {'pageviews': 9582, 'visitors': 908}
#       |- Teil B, Gruppe 1: {'pageviews': 6144, 'visitors': 373}
#       |- Teil B, Gruppe 2: {'pageviews': 4070, 'visitors': 329}
#       |- Teil B, Gruppe 3: {'pageviews': 3272, 'visitors': 198}
#   |- Jahrgangsstufentest Mathematik: {'pageviews': 425, 'visitors': 63}
#     |- 2017: {'pageviews': 35, 'visitors': 5}
#     |- 2016: {'pageviews': 53, 'visitors': 15}
#     |- 2015: {'pageviews': 82, 'visitors': 11}
#     |- 2018: {'pageviews': 62, 'visitors': 5}
#     |- 2019: {'pageviews': 123, 'visitors': 7}
