# %%
import json
import re
import mysql.connector

from IPython.display import display, Markdown

db = mysql.connector.connect(
    host="localhost",
    user="root",
    password="secret",
    port="3306",
    database="serlo"
)

def query(sql):
    c = db.cursor()
    c.execute(sql)
    
    return c.fetchall()

users = []
queryResult = query("""
    select id, username, description from user
""")

queryResult
# Out:
# [(1, 'arekkas', 'NULL'),
#  (2, 'devuser', 'NULL'),
#  (4, 'Deleted', 'NULL'),
#  (6, 'Legacy', 'NULL'),
#  (9, 'David', 'NULL'),
#  (10, 'Simon', 'NULL'),
#  (11, 'Michael', 'NULL'),
#  (12, 'Johanna', 'NULL'),
#  (13, 'Isy', 'NULL'),
#  (14, 'user', 'NULL'),
#  (15, 'Thorben', 'NULL'),
#  (16, 'Sufijen', 'NULL'),
#  (17, 'Consti_87', 'NULL'),
#  (18, 'hans', 'NULL'),
#  (19, 'mhicke', 'NULL'),
#  (20, 'EnQueMedida', 'NULL'),
#  (21, 'lisa.koehl', 'NULL'),
#  (22, 'Chuck_Norris', 'NULL'),
#  (23, 'mister100000', 'NULL'),
#  (24, 'bernhard', 'NULL'),
#  (25, 'marina', 'NULL'),
#  (26, 'hannahk', 'NULL'),
#  (27, 'konrad', 'NULL'),
#  (28, 'petersi', 'NULL'),
#  (29, 'Manu', 'NULL'),
#  (30, 'JohnFC', 'NULL'),
#  (31, 'HokkaidokÃƒÂ¼rbis', 'NULL'),
#  (32, 'n.uebelacker', 'NULL'),
#  (33, 'Tomifaz', 'NULL'),
#  (34, 'wernersbacher', 'NULL'),
#  (35, 'deKay', 'NULL'),
#  (36, 'Magi', 'NULL'),
#  (37, 'ralf-horn', 'NULL'),
#  (38, 'chizuna', 'NULL'),
#  (39, 'Melanie', 'NULL'),
# ...
