# %%
import pandas as pd
import mysql.connector

db = mysql.connector.connect(
    host="localhost",
    user="root",
    password="secret",
    port="3306",
    database="serlo"
)

event_log = pd.read_sql("""
    select event_log.id, user.username from event_log
    join user on user.id = event_log.actor_id
    where event_log.event_id = 5 and user.username != "Legacy"
""", db)
event_log
# Out:
#             id    username
# 0        37379      AK1701
# 1        37380      AK1701
# 2        37381      AK1701
# 3        37382      AK1701
# 4        37383      inyono
# ...        ...         ...
# 105635  386327  Mathewally
# 105636  386328  Mathewally
# 105637  386332       Astor
# 105638  386333    Kowalsky
# 105639  386334    Kowalsky
#
# [105640 rows x 2 columns]

# %%
df = event_log.groupby("username").count()
df.rename(columns={"id": "edits"}, inplace=True)
df.sort_values(["edits"], inplace=True, ascending=False)
df = df.head(400)
df
# Out:
#                  edits
# username
# kathongi          5474
# WandaPaetzold     3823
# Karin             3307
# chdieter          2776
# Nish              2667
# ...                ...
# Petz                 9
# Deleren              9
# Florian_Diercks      9
# jkempff              9
# Hannah-Jolie         9
#
# [400 rows x 1 columns]

# %%
from IPython.display import display, Markdown, HTML

display(Markdown("# Aktuelle Profilbilder der 200 aktivsten Autor:innen"))

result = []
result.append('<div style="width: 100%; display: flex; flex-flow: row wrap; justify-content: space-around;">')

for username in df.index:
    result.append('<div style="margin: 10px">')
    result.append(f'<img src="https://community.serlo.org/avatar/{username}" style="width: 100px; height: 100px;"/>')
    result.append(f'<p>{username}</p>')
    result.append('</div>')

result.append('</div>')

display(HTML("\n".join(result)))
# Out:
# # Aktuelle Profilbilder der 200 aktivsten Autor:innen
# <div style="width: 100%; display: flex; flex-flow: row wrap; justify-content: space-around;">
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/kathongi" style="width: 100px; height: 100px;"/>
# <p>kathongi</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/WandaPaetzold" style="width: 100px; height: 100px;"/>
# <p>WandaPaetzold</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Karin" style="width: 100px; height: 100px;"/>
# <p>Karin</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/chdieter" style="width: 100px; height: 100px;"/>
# <p>chdieter</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Nish" style="width: 100px; height: 100px;"/>
# <p>Nish</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/metzgaria" style="width: 100px; height: 100px;"/>
# <p>metzgaria</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Simon" style="width: 100px; height: 100px;"/>
# <p>Simon</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Renate" style="width: 100px; height: 100px;"/>
# <p>Renate</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/LinaMaria" style="width: 100px; height: 100px;"/>
# <p>LinaMaria</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Jonathan" style="width: 100px; height: 100px;"/>
# <p>Jonathan</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Kowalsky" style="width: 100px; height: 100px;"/>
# <p>Kowalsky</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/MarK97" style="width: 100px; height: 100px;"/>
# <p>MarK97</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Niggo" style="width: 100px; height: 100px;"/>
# <p>Niggo</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Kati_L" style="width: 100px; height: 100px;"/>
# <p>Kati_L</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/wolfgang" style="width: 100px; height: 100px;"/>
# <p>wolfgang</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Flora_Jana" style="width: 100px; height: 100px;"/>
# <p>Flora_Jana</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/JulianWR" style="width: 100px; height: 100px;"/>
# <p>JulianWR</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/LeaFa" style="width: 100px; height: 100px;"/>
# <p>LeaFa</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Knorrke" style="width: 100px; height: 100px;"/>
# <p>Knorrke</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/kazuki" style="width: 100px; height: 100px;"/>
# <p>kazuki</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Rebi" style="width: 100px; height: 100px;"/>
# <p>Rebi</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Lena09" style="width: 100px; height: 100px;"/>
# <p>Lena09</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/tobi_serlo" style="width: 100px; height: 100px;"/>
# <p>tobi_serlo</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Tinsaye" style="width: 100px; height: 100px;"/>
# <p>Tinsaye</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/adrian_wagner" style="width: 100px; height: 100px;"/>
# <p>adrian_wagner</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Katha26" style="width: 100px; height: 100px;"/>
# <p>Katha26</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/haberlm" style="width: 100px; height: 100px;"/>
# <p>haberlm</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Manuel_Voigt" style="width: 100px; height: 100px;"/>
# <p>Manuel_Voigt</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/HannaKulke" style="width: 100px; height: 100px;"/>
# <p>HannaKulke</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/LorenzHuber" style="width: 100px; height: 100px;"/>
# <p>LorenzHuber</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Vithusha" style="width: 100px; height: 100px;"/>
# <p>Vithusha</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/lotta_behrens" style="width: 100px; height: 100px;"/>
# <p>lotta_behrens</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Marvin" style="width: 100px; height: 100px;"/>
# <p>Marvin</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Hannes" style="width: 100px; height: 100px;"/>
# <p>Hannes</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/NiCi" style="width: 100px; height: 100px;"/>
# <p>NiCi</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Lenali" style="width: 100px; height: 100px;"/>
# <p>Lenali</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Michi" style="width: 100px; height: 100px;"/>
# <p>Michi</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Tobias" style="width: 100px; height: 100px;"/>
# <p>Tobias</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/inyono" style="width: 100px; height: 100px;"/>
# <p>inyono</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/botho" style="width: 100px; height: 100px;"/>
# <p>botho</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/IvanP" style="width: 100px; height: 100px;"/>
# <p>IvanP</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/RobinKibart" style="width: 100px; height: 100px;"/>
# <p>RobinKibart</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/SebSoGa" style="width: 100px; height: 100px;"/>
# <p>SebSoGa</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/JonasBl" style="width: 100px; height: 100px;"/>
# <p>JonasBl</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Viki" style="width: 100px; height: 100px;"/>
# <p>Viki</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/motto1" style="width: 100px; height: 100px;"/>
# <p>motto1</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Simone_Heinrich" style="width: 100px; height: 100px;"/>
# <p>Simone_Heinrich</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/emir_nbh" style="width: 100px; height: 100px;"/>
# <p>emir_nbh</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/roehren" style="width: 100px; height: 100px;"/>
# <p>roehren</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Ronnit" style="width: 100px; height: 100px;"/>
# <p>Ronnit</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/franzi" style="width: 100px; height: 100px;"/>
# <p>franzi</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Bernhard-Strauss" style="width: 100px; height: 100px;"/>
# <p>Bernhard-Strauss</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/sabi21" style="width: 100px; height: 100px;"/>
# <p>sabi21</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Susi" style="width: 100px; height: 100px;"/>
# <p>Susi</p>
# </div>
# <div style="margin: 10px">
# <img src="https://community.serlo.org/avatar/Monika_Wirthl" style="width: 100px; height: 100px;"/>
# <p>Monika_Wirthl</p>
# </div>
# <div style="margin: 10px">
# <img
