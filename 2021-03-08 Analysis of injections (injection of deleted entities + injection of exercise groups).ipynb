# %% [markdown]
# # Helper

# %%
import json
import re
import mysql.connector

from IPython.display import display, Markdown

db = mysql.connector.connect(
    host="localhost",
    user="root",
    password="secret",
    port="3306",
    database="serlo"
)

def cached(func):
    cache = dict()
    
    def return_func(arg):
        if (arg in cache):
            return cache[arg]
        else:
            result = func(arg)
            cache[arg] = result
            return result
    
    return return_func

def query(sql):
    c = db.cursor()
    c.execute(sql)
    
    return c.fetchall()

def querySingleton(sql):
    return [ x[0] for x in query(sql) ]

def getContent(entityId):
    return json.loads(query("""
        select entity_revision_field.value from entity
        join entity_revision on entity_revision.id = entity.current_revision_id
        join entity_revision_field on entity_revision_field.entity_revision_id = entity_revision.id
        where entity.id = %s and entity_revision_field.field = "content"
    """ % entityId)[0][0])

def getType(entityId):
    return query("""
        select type.name from entity
        join type on type.id = entity.type_id
        where entity.id = %s
    """ % entityId)[0][0]

def getTrashed(entityId):
    return query("""
        select uuid.trashed from entity
        join uuid on uuid.id = entity.id
        where entity.id = %s
    """ % entityId)[0][0]

def getInjectionIds(content, e=0):
    if "plugin" in content:
        yield from getInjectionIdsEdtrIo(content, e)
    else:
        yield from getInjectionIdsLegacy(content)
    
def getInjectionIdsLegacy(content):
    regex = re.compile(r">\[[^\]]+\]\(\/(\d+)\)")
    
    for row in content:
        for column in row:
            for match in regex.finditer(column["content"]):
                yield int(match.group(1))

def getInjectionIdsEdtrIo(content, e):
    if isinstance(content, list):
        for child in content:
            yield from getInjectionIdsEdtrIo(child, e)
    if isinstance(content, dict):
        if "plugin" in content and content["plugin"] == "injection":
            try:
                yield int(content["state"][1:])
            except ValueError:
                print("Wrong state in id %s: %s" % (e, content["state"]))
        else:
            for child in content.values():
                yield from getInjectionIdsEdtrIo(child, e)

# %%
from json import JSONDecodeError

entityIds = querySingleton("""
    select entity.id from entity
    join uuid on uuid.id = entity.id
    join type on type.id = entity.type_id
    where type.name != "comment"
        and type.name != "video"
        and type.name != "course"
        and type.name != "input-number-exact-match-challenge"
        and type.name != "input-expression-equal-match-challenge"
        and type.name != "input-string-normalized-match-challenge"
        and type.name != "multiple-choice-right-answer"
        and type.name != "multiple-choice-wrong-answer"
        and type.name != "single-choice-right-answer"
        and type.name != "single-choice-wrong-answer"
        and entity.current_revision_id is not null
""")

entities = dict()

for entityId in entityIds:
    try:
        content = getContent(entityId)
        injectedIds = list(getInjectionIds(content, entityId))
        
        entities[entityId] = {
            "content": content,
            "id": entityId,
            "trashed": getTrashed(entityId),
            "type": getType(entityId),
            "injectedIds": injectedIds,
            "injectedInto": []
        }
    except JSONDecodeError:
        print("Error with id: %s" % entityId)
    except IndexError:
        print("Error with id: %s" % entityId)

for entity in entities.values():
    for injectedId in entity["injectedIds"]:
        if injectedId in entities:
            entities[injectedId]["injectedInto"].append(entity["id"])
# Out:
# Error with id: 14573
# Wrong state in id 34159: 1
# Error with id: 41722
# Error with id: 41729
# Wrong state in id 158346:
# Wrong state in id 174232:

# %% [markdown]
# # Liste von gelöschten Inhalten, die woanders inkludiert werden

# %%
for entity in entities.values():
    if entity["trashed"] == 1 and len(entity["injectedInto"]) > 0 and any(
      i in entities and entities[i]["trashed"] == 0 for i in entity["injectedInto"]
    ):
        display(Markdown("# ID: %s" % entity["id"]))
        display(Markdown("Der Serlo-Inhalt https://serlo.org/%s ist als gelöscht markiert, wird aber in folgenden anderen Inhalten eingebunden:" % entity["id"]))
        display(Markdown("\n".join(("* https://serlo.org/%s" % i for i in entity["injectedInto"]))))
# Out:
# # ID: 4701
# Der Serlo-Inhalt https://serlo.org/4701 ist als gelöscht markiert, wird aber in folgenden anderen Inhalten eingebunden:
# * https://serlo.org/36856
# # ID: 4705
# Der Serlo-Inhalt https://serlo.org/4705 ist als gelöscht markiert, wird aber in folgenden anderen Inhalten eingebunden:
# * https://serlo.org/36856
# # ID: 4745
# Der Serlo-Inhalt https://serlo.org/4745 ist als gelöscht markiert, wird aber in folgenden anderen Inhalten eingebunden:
# * https://serlo.org/37396
# # ID: 4749
# Der Serlo-Inhalt https://serlo.org/4749 ist als gelöscht markiert, wird aber in folgenden anderen Inhalten eingebunden:
# * https://serlo.org/37396
# # ID: 6155
# Der Serlo-Inhalt https://serlo.org/6155 ist als gelöscht markiert, wird aber in folgenden anderen Inhalten eingebunden:
# * https://serlo.org/1727
# * https://serlo.org/36702
# # ID: 9501
# Der Serlo-Inhalt https://serlo.org/9501 ist als gelöscht markiert, wird aber in folgenden anderen Inhalten eingebunden:
# * https://serlo.org/1515
# # ID: 10505
# Der Serlo-Inhalt https://serlo.org/10505 ist als gelöscht markiert, wird aber in folgenden anderen Inhalten eingebunden:
# * https://serlo.org/1865
# # ID: 13189
# Der Serlo-Inhalt https://serlo.org/13189 ist als gelöscht markiert, wird aber in folgenden anderen Inhalten eingebunden:
# * https://serlo.org/1817
# # ID: 14809
# Der Serlo-Inhalt https://serlo.org/14809 ist als gelöscht markiert, wird aber in folgenden anderen Inhalten eingebunden:
# * https://serlo.org/2097
# # ID: 43875
# Der Serlo-Inhalt https://serlo.org/43875 ist als gelöscht markiert, wird aber in folgenden anderen Inhalten eingebunden:
# * https://serlo.org/143554
# # ID: 60266
# Der Serlo-Inhalt https://serlo.org/60266 ist als gelöscht markiert, wird aber in folgenden anderen Inhalten eingebunden:
# * https://serlo.org/2107
# # ID: 60270
# Der Serlo-Inhalt https://serlo.org/60270 ist als gelöscht markiert, wird aber in folgenden anderen Inhalten eingebunden:
# * https://serlo.org/2107
# # ID: 64024
# Der Serlo-Inhalt https://serlo.org/64024 ist als gelöscht markiert, wird aber in folgenden anderen Inhalten eingebunden:
# * https://serlo.org/63999
# # ID: 128258
# Der Serlo-Inhalt https://serlo.org/128258 ist als gelöscht markiert, wird aber in folgenden anderen Inhalten eingebunden:
# * https://serlo.org/127879
# # ID: 128265
# Der Serlo-Inhalt https://serlo.org/128265 ist als gelöscht markiert, wird aber in folgenden anderen Inhalten eingebunden:
# * https://serlo.org/127879
# # ID: 136640
# Der Serlo-Inhalt https://serlo.org/136640 ist als gelöscht markiert, wird aber in folgenden anderen Inhalten eingebunden:
# * https://serlo.org/132770
# # ID: 136826
# Der Serlo-Inhalt https://serlo.org/136826 ist als gelöscht markiert, wird aber in folgenden anderen Inhalten eingebunden:
# * https://serlo.org/132783

# %% [markdown]
# # Liste inkludierter Aufgabensammlungen

# %%
for entity in entities.values():
    if entity["trashed"] == 0 and entity["type"] == "grouped-text-exercise" and len(entity["injectedInto"]) > 0:
        print("Id: %s" % entity["id"])
        print("Injected into: %s" % entity["injectedInto"])
        print()
# Out:
# Id: 2225
# Injected into: [1619, 1773, 2173]
#
# Id: 2233
# Injected into: [1619, 1773]
#
# Id: 2267
# Injected into: [72262]
#
# Id: 2303
# Injected into: [1827]
#
# Id: 2307
# Injected into: [67468]
#
# Id: 2345
# Injected into: [149480]
#
# Id: 2391
# Injected into: [1797]
#
# Id: 2403
# Injected into: [1797, 109508]
#
# Id: 2463
# Injected into: [67468]
#
# Id: 2505
# Injected into: [2195]
#
# Id: 2535
# Injected into: [1797]
#
# Id: 2569
# Injected into: [1577]
#
# Id: 2629
# Injected into: [1797]
#
# Id: 2669
# Injected into: [1599]
#
# Id: 2673
# Injected into: [1599]
#
# Id: 2677
# Injected into: [1615]
#
# Id: 2685
# Injected into: [67463]
#
# Id: 2697
# Injected into: [1615]
#
# Id: 2701
# Injected into: [1615]
#
# Id: 2725
# Injected into: [30259]
#
# Id: 2729
# Injected into: [67463]
#
# Id: 2739
# Injected into: [1577]
#
# Id: 2743
# Injected into: [2173]
#
# Id: 2781
# Injected into: [19549, 30255]
#
# Id: 2785
# Injected into: [27803]
#
# Id: 2801
# Injected into: [51557]
#
# Id: 2819
# Injected into: [30250]
#
# Id: 2851
# Injected into: [51557]
#
# Id: 2875
# Injected into: [51557]
#
# Id: 2883
# Injected into: [19549]
#
# Id: 3017
# Injected into: [1533]
#
# Id: 3021
# Injected into: [1533]
#
# Id: 3195
# Injected into: [1533]
#
# Id: 3551
# Injected into: [2005]
#
# Id: 3563
# Injected into: [2005]
#
# Id: 3587
# Injected into: [2005]
#
# Id: 3605
# Injected into: [1747, 2005, 2051]
#
# Id: 3609
# Injected into: [2051, 90400]
#
# Id: 3631
# Injected into: [1525, 18645, 31055]
#
# Id: 3635
# Injected into: [1525]
#
# Id: 3639
# Injected into: [187200]
#
# Id: 3647
# Injected into: [18645, 31055]
#
# Id: 3675
# Injected into: [18645, 31055]
#
# Id: 3697
# Injected into: [1499]
#
# Id: 3701
# Injected into: [1499, 19006]
#
# Id: 3705
# Injected into: [19006]
#
# Id: 3709
# Injected into: [19006]
#
# Id: 3739
# Injected into: [19071]
#
# Id: 3743
# Injected into: [19071]
#
# Id: 3747
# Injected into: [19071]
#
# Id: 3761
# Injected into: [1499]
#
# Id: 3769
# Injected into: [19071]
#
# Id: 3773
# Injected into: [19179]
#
# Id: 3813
# Injected into: [1577]
#
# Id: 3825
# Injected into: [20661]
#
# Id: 3829
# Injected into: [19179]
#
# Id: 3837
# Injected into: [1499]
#
# Id: 3841
# Injected into: [1499]
#
# Id: 3849
# Injected into: [19179]
#
# Id: 3865
# Injected into: [19071]
#
# Id: 3869
# Injected into: [1499, 19071]
#
# Id: 3873
# Injected into: [19071]
#
# Id: 3877
# Injected into: [19071]
#
# Id: 3899
# Injected into: [1605]
#
# Id: 3903
# Injected into: [187272]
#
# Id: 3907
# Injected into: [18645, 31055]
#
# Id: 3981
# Injected into: [1865]
#
# Id: 4247
# Injected into: [1509, 187202]
#
# Id: 4251
# Injected into: [1509]
#
# Id: 4255
# Injected into: [1509]
#
# Id: 4265
# Injected into: [1581, 32996, 99141]
#
# Id: 4299
# Injected into: [1581, 32996]
#
# Id: 4351
# Injected into: [1497]
#
# Id: 4355
# Injected into: [1659]
#
# Id: 4359
# Injected into: [187202]
#
# Id: 4413
# Injected into: [1527]
#
# Id: 4421
# Injected into: [51074]
#
# Id: 4581
# Injected into: [1551]
#
# Id: 4595
# Injected into: [1551]
#
# Id: 4599
# Injected into: [1551]
#
# Id: 4605
# Injected into: [187200]
#
# Id: 4621
# Injected into: [187200]
#
# Id: 4637
# Injected into: [18645, 31055]
#
# Id: 4693
# Injected into: [1677, 18645, 31055]
#
# Id: 4709
# Injected into: [37145]
#
# Id: 4713
# Injected into: [37145]
#
# Id: 4753
# Injected into: [36833]
#
# Id: 4761
# Injected into: [36833]
#
# Id: 4859
# Injected into: [1527]
#
# Id: 4863
# Injected into: [1497]
#
# Id: 4867
# Injected into: [1659]
#
# Id: 4871
# Injected into: [51074]
#
# Id: 4879
# Injected into: [2183]
#
# Id: 4945
# Injected into: [2171]
#
# Id: 4953
# Injected into: [2171]
#
# Id: 5059
# Injected into: [1619]
#
# Id: 5063
# Injected into: [1619]
#
# Id: 5209
# Injected into: [2171]
#
# Id: 5261
# Injected into: [2183]
#
# Id: 5497
# Injected into: [1867]
#
# Id: 5505
# Injected into: [1867]
#
# Id: 5535
# Injected into: [1867]
#
# Id: 5557
# Injected into: [1511]
#
# Id: 5591
# Injected into: [1511]
#
# Id: 5613
# Injected into: [1511]
#
# Id: 5617
# Injected into: [1511]
#
# Id: 5625
# Injected into: [1511]
#
# Id: 5629
# Injected into: [1511]
#
# Id: 5647
# Injected into: [1511]
#
# Id: 5651
# Injected into: [1511]
#
# Id: 5655
# Injected into: [1511]
#
# Id: 5659
# Injected into: [1511]
#
# Id: 5673
# Injected into: [1549]
#
# Id: 5679
# Injected into: [1513, 1549]
#
# Id: 5683
# Injected into: [1549]
#
# Id: 5687
# Injected into: [1513]
#
# Id: 5727
# Injected into: [90400]
#
# Id: 5791
# Injected into: [1575, 1839, 19549, 126862]
#
# Id: 6031
# Injected into: [2067]
#
# Id: 6035
# Injected into: [2067]
#
# Id: 6039
# Injected into: [2067]
#
# Id: 6043
# Injected into: [2067]
#
# Id: 6047
# Injected into: [2067]
#
# Id: 6109
# Injected into: [1763]
#
# Id: 6141
# Injected into: [1763]
#
# Id: 6145
# Injected into: [1763]
#
# Id: 6245
# Injected into: [144838]
#
# Id: 6275
# Injected into: [1763]
#
# Id: 6541
# Injected into: [1575, 1839]
#
# Id: 6545
# Injected into: [126870]
#
# Id: 6549
# Injected into: [126870]
#
# Id: 6553
# Injected into: [126870]
#
# Id: 6557
# Injected into: [125409]
#
# Id: 6565
# Injected into: [125409]
#
# Id: 6623
# Injected into: [1575, 1839, 126862]
#
# Id: 6627
# Injected into: [126862]
#
# Id: 6631
# Injected into: [19549]
#
# Id: 6635
# Injected into: [1511, 1575, 1839, 126865]
#
# Id: 6639
# Injected into: [1511, 126865]
#
# Id: 6643
# Injected into: [125409]
#
# Id: 6647
# Injected into: [1575, 1839]
#
# Id: 6655
# Injected into: [19549, 125409]
#
# Id: 6659
# Injected into: [126868]
#
# Id: 6681
# Injected into: [2079]
#
# Id: 6685
# Injected into: [2079]
#
# Id: 6689
# Injected into: [2079]
#
# Id: 6693
# Injected into: [2079]
#
# Id: 6765
# Injected into: [1801]
#
# Id: 7051
# Injected into: [2183]
#
# Id: 7213
# Injected into: [62198]
#
# Id: 7249
# Injected into: [62559, 62559]
#
# Id: 7253
# Injected into: [62319]
#
# Id: 7257
# Injected into: [62319]
#
# Id: 7261
# Injected into: [62319, 62559]
#
# Id: 7301
# Injected into: [62323]
#
# Id: 7305
# Injected into: [62198]
#
# Id: 7309
# Injected into: [62323]
#
# Id: 7317
# Injected into: [62323]
#
# Id: 7851
# Injected into: [20138]
#
# Id: 7859
# Injected into: [20138]
#
# Id: 7931
# Injected into: [1619]
#
# Id: 8087
# Injected into: [54317]
#
# Id: 8105
# Injected into: [196570]
#
# Id: 8113
# Injected into: [196570]
#
# Id: 8117
# Injected into: [196570]
#
# Id: 8315
# Injected into: [1677]
#
# Id: 8359
# Injected into: [1677]
#
# Id: 8371
# Injected into: [187200]
#
# Id: 8379
# Injected into: [1677]
#
# Id: 8455
# Injected into: [1677]
#
# Id: 8475
# Injected into: [1677]
#
# Id: 8523
# Injected into: [18645, 31055]
#
# Id: 8565
# Injected into: [1605, 187272]
#
# Id: 8573
# Injected into: [187272]
#
# Id: 8665
# Injected into: [1525]
#
# Id: 8669
# Injected into: [1525]
#
# Id: 8699
# Injected into: [1677]
#
# Id: 8723
# Injected into: [1779]
#
# Id: 8735
# Injected into: [1779]
#
# Id: 8779
# Injected into: [1605, 187272]
#
# Id: 8789
# Injected into: [1785]
#
# Id: 8807
# Injected into: [1525]
#
# Id: 8867
# Injected into: [187272]
#
# Id: 8881
# Injected into: [187272]
#
# Id: 8915
# Injected into: [1689]
#
# Id: 8935
# Injected into: [19549]
#
# Id: 8939
# Injected into: [1599]
#
# Id: 8943
# Injected into: [1599, 19549]
#
# Id: 9101
# Injected into: [1571]
#
# Id: 9113
# Injected into: [1571]
#
# Id: 9331
# Injected into: [54317]
#
# Id: 9463
# Injected into: [1605]
#
# Id: 9467
# Injected into: [187272]
#
# Id: 9481
# Injected into: [1531, 2195]
#
# Id: 9545
# Injected into: [1619]
#
# Id: 9633
# Injected into: [31251]
#
# Id: 9637
# Injected into: [1639, 156048]
#
# Id: 9643
# Injected into: [31251]
#
# Id: 9775
# Injected into: [2153]
#
# Id: 9779
# Injected into: [2153]
#
# Id: 9783
# Injected into: [2153]
#
# Id: 9803
# Injected into: [1939, 105958]
#
# Id: 9807
# Injected into: [1939, 105958]
#
# Id: 9833
# Injected into: [1957]
#
# Id: 9837
# Injected into: [2195, 51557]
#
# Id: 9841
# Injected into: [1531]
#
# Id: 9849
# Injected into: [1531, 51557]
#
# Id: 9853
# Injected into: [1531, 51557]
#
# Id: 9887
# Injected into: [1957]
#
# Id: 9945
# Injected into: [18956]
#
# Id: 9949
# Injected into: [18956]
#
# Id: 9953
# Injected into: [19071]
#
# Id: 9957
# Injected into: [19071]
#
# Id: 9961
# Injected into: [19071]
#
# Id: 9965
# Injected into: [19071]
#
# Id: 9969
# Injected into: [18956]
#
# Id: 9973
# Injected into: [19006]
#
# Id: 9981
# Injected into: [19071]
#
# Id: 9987
# Injected into: [19071]
#
# Id: 9991
# Injected into: [19071]
#
# Id: 9999
# Injected into: [19071]
#
# Id: 10133
# Injected into: [62198]
#
# Id: 10137
# Injected into: [62198]
#
# Id: 10167
# Injected into: [2183]
#
# Id: 10557
# Injected into: [21117]
#
# Id: 10561
# Injected into: [21117]
#
# Id: 10565
# Injected into: [21117]
#
# Id: 10569
# Injected into: [21117]
#
# Id: 10573
# Injected into: [21117]
#
# Id: 10679
# Injected into: [62323]
#
# Id: 10691
# Injected into: [62323]
#
# Id: 10835
# Injected into: [2073]
#
# Id: 10863
# Injected into: [2073]
#
# Id: 10961
# Injected into: [1995]
#
# Id: 10965
# Injected into: [1995]
#
# Id: 10969
# Injected into: [1995]
#
# Id: 11229
# Injected into: [51533]
#
# Id: 11233
# Injected into: [51533]
#
# Id: 11237
# Injected into: [51533]
#
# Id: 11613
# Injected into: [1989]
#
# Id: 11777
# Injected into: [2019]
#
# Id: 11781
# Injected into: [2019]
#
# Id: 11785
# Injected into: [2019]
#
# Id: 11813
# Injected into: [2021, 2097]
#
# Id: 11817
# Injected into: [2021, 2097]
#
# Id: 11821
# Injected into: [2097]
#
# Id: 11827
# Injected into: [2023]
#
# Id: 12137
# Injected into: [1701]
#
# Id: 12141
# Injected into: [1701]
#
# Id: 12145
# Injected into: [1701]
#
# Id: 12157
# Injected into: [55514]
#
# Id: 12163
# Injected into: [55514]
#
# Id: 12185
# Injected into: [55514]
#
# Id: 12209
# Injected into: [55514]
#
# Id: 12213
# Injected into: [105958]
#
# Id: 12225
# Injected into: [105958]
#
# Id: 12325
# Injected into: [105385]
#
# Id: 12333
# Injected into: [105385]
#
# Id: 12413
# Injected into: [56380]
#
# Id: 12513
# Injected into: [56380]
#
# Id: 12587
# Injected into: [2109]
#
# Id: 12591
# Injected into: [2109]
#
# Id: 12595
# Injected into: [2109]
#
# Id: 12601
# Injected into: [2109]
#
# Id: 12607
# Injected into: [2109]
#
# Id: 12611
# Injected into: [2109]
#
# Id: 12615
# Injected into: [2109]
#
# Id: 12619
# Injected into: [2109]
#
# Id: 12623
# Injected into: [2109]
#
# Id: 12631
# Injected into: [2109]
#
# Id: 12637
# Injected into: [2109]
#
# Id: 12655
# Injected into: [1783]
#
# Id: 12659
# Injected into: [1783]
#
# Id: 12663
# Injected into: [1783]
#
# Id: 12667
# Injected into: [1783]
#
# Id: 12671
# Injected into: [1783]
#
# Id: 12675
# Injected into: [1783]
#
# Id: 12679
# Injected into: [1783]
#
# Id: 12683
# Injected into: [1783]
#
# Id: 12687
# Injected into: [1783]
#
# Id: 12691
# Injected into: [1783]
#
# Id: 12695
# Injected into: [1783]
#
# Id: 12699
# Injected into: [2109]
#
# Id: 12703
# Injected into: [2109]
#
# Id: 12707
# Injected into: [2109]
#
# Id: 12711
# Injected into: [2109]
#
# Id: 12715
# Injected into: [2109]
#
# Id: 12719
# Injected into: [2109]
#
# Id: 12739
# Injected into: [2137]
#
# Id: 12815
# Injected into: [1573, 1777]
#
# Id: 12821
# Injected into: [1715, 101977]
#
# Id: 12833
# Injected into: [101977]
#
# Id: 12863
# Injected into: [1715, 101977]
#
# Id: 12867
# Injected into: [101977]
#
# Id: 12877
# Injected into: [101977]
#
# Id: 12899
# Injected into: [1715]
#
# Id: 12921
# Injected into: [101977]
#
# Id: 12925
# Injected into: [101977]
#
# Id: 12927
# Injected into: [101977]
#
# Id: 12973
# Injected into: [101977]
#
# Id: 12993
# Injected into: [101977]
#
# Id: 13005
# Injected into: [2137]
#
# Id: 13009
# Injected into: [2137]
#
# Id: 13091
# Injected into: [1907]
#
# Id: 13095
# Injected into: [1907]
#
# Id: 13099
# Injected into: [1907]
#
# Id: 13105
# Injected into: [1907]
#
# Id: 13109
# Injected into: [1907]
#
# Id: 13113
# Injected into: [1907]
#
# Id: 13119
# Injected into: [2145]
#
# Id: 13125
# Injected into: [2145]
#
# Id: 13129
# Injected into: [2145]
#
# Id: 13133
# Injected into: [2145]
#
# Id: 13207
# Injected into: [2099]
#
# Id: 13219
# Injected into: [2099]
#
# Id: 13223
# Injected into: [2099]
#
# Id: 13227
# Injected into: [2099]
#
# Id: 13231
# Injected into: [2099]
#
# Id: 13237
# Injected into: [2097]
#
# Id: 13241
# Injected into: [2097]
#
# Id: 13249
# Injected into: [2097]
#
# Id: 13253
# Injected into: [2097]
#
# Id: 13257
# Injected into: [2097]
#
# Id: 13283
# Injected into: [2097]
#
# Id: 13287
# Injected into: [2097]
#
# Id: 13291
# Injected into: [2097]
#
# Id: 13297
# Injected into: [2097]
#
# Id: 13301
# Injected into: [2097]
#
# Id: 13317
# Injected into: [67468]
#
# Id: 13329
# Injected into: [67468]
#
# Id: 13339
# Injected into: [2097]
#
# Id: 13343
# Injected into: [2097]
#
# Id: 13347
# Injected into: [2097]
#
# Id: 13351
# Injected into: [2097]
#
# Id: 13377
# Injected into: [2097]
#
# Id: 13387
# Injected into: [2097]
#
# Id: 13405
# Injected into: [2097]
#
# Id: 13413
# Injected into: [2097]
#
# Id: 13457
# Injected into: [67463]
#
# Id: 13473
# Injected into: [2097]
#
# Id: 13477
# Injected into: [2097]
#
# Id: 13483
# Injected into: [2099]
#
# Id: 13487
# Injected into: [2099]
#
# Id: 13491
# Injected into: [2099]
#
# Id: 13495
# Injected into: [2099]
#
# Id: 13501
# Injected into: [2099]
#
# Id: 13505
# Injected into: [2099]
#
# Id: 13647
# Injected into: [1639]
#
# Id: 13669
# Injected into: [1639]
#
# Id: 13685
# Injected into: [67529]
#
# Id: 13689
# Injected into: [67529]
#
# Id: 13697
# Injected into: [67529]
#
# Id: 13747
# Injected into: [20661]
#
# Id: 13775
# Injected into: [1655]
#
# Id: 13787
# Injected into: [1655]
#
# Id: 13791
# Injected into: [1655]
#
# Id: 13837
# Injected into: [2201]
#
# Id: 13841
# Injected into: [2201]
#
# Id: 13845
# Injected into: [2201]
#
# Id: 13849
# Injected into: [2201]
#
# Id: 13963
# Injected into: [67463]
#
# Id: 13967
# Injected into: [67463]
#
# Id: 14057
# Injected into: [1803]
#
# Id: 14061
# Injected into: [117195]
#
# Id: 14065
# Injected into: [117197]
#
# Id: 14119
# Injected into: [2067]
#
# Id: 14123
# Injected into: [2067]
#
# Id: 14127
# Injected into: [2067]
#
# Id: 14177
# Injected into: [2151]
#
# Id: 14181
# Injected into: [2151]
#
# Id: 14681
# Injected into: [1509]
#
# Id: 14707
# Injected into: [1509]
#
# Id: 14733
# Injected into: [1509]
#
# Id: 14855
# Injected into: [19125]
#
# Id: 14859
# Injected into: [19125]
#
# Id: 14899
# Injected into: [1607]
#
# Id: 14903
# Injected into: [1607]
#
# Id: 14913
# Injected into: [19071]
#
# Id: 14917
# Injected into: [19071]
#
# Id: 14921
# Injected into: [19071]
#
# Id: 14925
# Injected into: [19071]
#
# Id: 14929
# Injected into: [19071]
#
# Id: 14933
# Injected into: [19071]
#
# Id: 14937
# Injected into: [19071]
#
# Id: 14983
# Injected into: [19125]
#
# Id: 14987
# Injected into: [19125]
#
# Id: 14991
# Injected into: [19125]
#
# Id: 14995
# Injected into: [19125]
#
# Id: 15023
# Injected into: [2201]
#
# Id: 15027
# Injected into: [18645, 31055]
#
# Id: 15037
# Injected into: [1631]
#
# Id: 15065
# Injected into: [1781]
#
# Id: 15069
# Injected into: [1781]
#
# Id: 15073
# Injected into: [1781]
#
# Id: 15087
# Injected into: [1631, 1781]
#
# Id: 15091
# Injected into: [1781]
#
# Id: 15099
# Injected into: [1781]
#
# Id: 15165
# Injected into: [1781]
#
# Id: 15169
# Injected into: [1631]
#
# Id: 15173
# Injected into: [19125]
#
# Id: 15177
# Injected into: [1781]
#
# Id: 15255
# Injected into: [1631, 19143]
#
# Id: 15259
# Injected into: [1631, 19143]
#
# Id: 15263
# Injected into: [1631, 19143]
#
# Id: 15267
# Injected into: [19143]
#
# Id: 15271
# Injected into: [19143]
#
# Id: 15397
# Injected into: [27803]
#
# Id: 20145
# Injected into: [20138]
#
# Id: 20164
# Injected into: [20138]
#
# Id: 20186
# Injected into: [20138]
#
# Id: 20439
# Injected into: [67463]
#
# Id: 20457
# Injected into: [67463]
#
# Id: 20549
# Injected into: [67468]
#
# Id: 20557
# Injected into: [67468]
#
# Id: 20574
# Injected into: [67468]
#
# Id: 20936
# Injected into: [27801]
#
# Id: 20942
# Injected into: [27801]
#
# Id: 20952
# Injected into: [27801]
#
# Id: 21095
# Injected into: [27801]
#
# Id: 21101
# Injected into: [27801]
#
# Id: 21107
# Injected into: [27801]
#
# Id: 21782
# Injected into: [27803]
#
# Id: 28208
# Injected into: [187202]
#
# Id: 28565
# Injected into: [28557]
#
# Id: 28584
# Injected into: [28557]
#
# Id: 30582
# Injected into: [18956]
#
# Id: 36872
# Injected into: [37183]
#
# Id: 36878
# Injected into: [37183]
#
# Id: 36903
# Injected into: [37183]
#
# Id: 36909
# Injected into: [37186]
#
# Id: 36915
# Injected into: [37186]
#
# Id: 36920
# Injected into: [37186]
#
# Id: 42297
# Injected into: [42242]
#
# Id: 42633
# Injected into: [42551]
#
# Id: 42666
# Injected into: [42551]
#
# Id: 44163
# Injected into: [1573, 1777]
#
# Id: 44173
# Injected into: [1777]
#
# Id: 44181
# Injected into: [1573]
#
# Id: 44680
# Injected into: [1573]
#
# Id: 44688
# Injected into: [1573]
#
# Id: 50011
# Injected into: [1781]
#
# Id: 50025
# Injected into: [1781]
#
# Id: 50027
# Injected into: [1781]
#
# Id: 50047
# Injected into: [1781]
#
# Id: 50058
# Injected into: [1781]
#
# Id: 50061
# Injected into: [1781]
#
# Id: 50501
# Injected into: [135687, 145470]
#
# Id: 50627
# Injected into: [54352]
#
# Id: 51422
# Injected into: [1835]
#
# Id: 51430
# Injected into: [1835]
#
# Id: 51436
# Injected into: [1835]
#
# Id: 51473
# Injected into: [1835, 51561]
#
# Id: 51475
# Injected into: [1835, 51561]
#
# Id: 51477
# Injected into: [1835, 51561]
#
# Id: 51480
# Injected into: [1835, 51561]
#
# Id: 51582
# Injected into: [51551]
#
# Id: 51594
# Injected into: [51551]
#
# Id: 51596
# Injected into: [51551]
#
# Id: 52403
# Injected into: [51557]
#
# Id: 52832
# Injected into: [1869]
#
# Id: 53014
# Injected into: [1963]
#
# Id: 53024
# Injected into: [1963]
#
# Id: 53179
# Injected into: [1869]
#
# Id: 53209
# Injected into: [54038]
#
# Id: 53213
# Injected into: [53038]
#
# Id: 53216
# Injected into: [1569, 54038]
#
# Id: 53240
# Injected into: [53038]
#
# Id: 53244
# Injected into: [53038]
#
# Id: 53648
# Injected into: [1963]
#
# Id: 54007
# Injected into: [1963]
#
# Id: 54284
# Injected into: [50567]
#
# Id: 54288
# Injected into: [50567]
#
# Id: 54751
# Injected into: [36162]
#
# Id: 54799
# Injected into: [1557]
#
# Id: 54911
# Injected into: [36162]
#
# Id: 55143
# Injected into: [1639]
#
# Id: 55147
# Injected into: [1639]
#
# Id: 55155
# Injected into: [1639]
#
# Id: 55334
# Injected into: [1639]
#
# Id: 55344
# Injected into: [1639]
#
# Id: 55676
# Injected into: [1961]
#
# Id: 56956
# Injected into: [56795]
#
# Id: 56963
# Injected into: [56795]
#
# Id: 56969
# Injected into: [56795]
#
# Id: 56975
# Injected into: [56795]
#
# Id: 56981
# Injected into: [56795]
#
# Id: 56997
# Injected into: [56795]
#
# Id: 57001
# Injected into: [56795]
#
# Id: 57005
# Injected into: [56795]
#
# Id: 57040
# Injected into: [56795]
#
# Id: 57045
# Injected into: [56795]
#
# Id: 57049
# Injected into: [56795]
#
# Id: 58828
# Injected into: [63064]
#
# Id: 58887
# Injected into: [63064]
#
# Id: 58901
# Injected into: [63064]
#
# Id: 60237
# Injected into: [1573]
#
# Id: 60316
# Injected into: [1737]
#
# Id: 60320
# Injected into: [1737]
#
# Id: 60323
# Injected into: [50515]
#
# Id: 60326
# Injected into: [1737]
#
# Id: 60366
# Injected into: [50515]
#
# Id: 61030
# Injected into: [1715]
#
# Id: 61034
# Injected into: [1715]
#
# Id: 61401
# Injected into: [161362]
#
# Id: 61868
# Injected into: [61990]
#
# Id: 61874
# Injected into: [61990]
#
# Id: 61886
# Injected into: [61990]
#
# Id: 62070
# Injected into: [62140, 62546]
#
# Id: 62076
# Injected into: [62140]
#
# Id: 62077
# Injected into: [62546]
#
# Id: 62094
# Injected into: [62140, 62546]
#
# Id: 62419
# Injected into: [62467]
#
# Id: 62442
# Injected into: [62467]
#
# Id: 62445
# Injected into: [62467]
#
# Id: 62918
# Injected into: [62926]
#
# Id: 62964
# Injected into: [62926]
#
# Id: 63009
# Injected into: [63077]
#
# Id: 63036
# Injected into: [63077]
#
# Id: 64874
# Injected into: [1533]
#
# Id: 65129
# Injected into: [125651]
#
# Id: 66751
# Injected into: [67255]
#
# Id: 66774
# Injected into: [67255]
#
# Id: 66781
# Injected into: [67255]
#
# Id: 66989
# Injected into: [67319]
#
# Id: 67042
# Injected into: [67350]
#
# Id: 67046
# Injected into: [67350]
#
# Id: 67099
# Injected into: [67428]
#
# Id: 67111
# Injected into: [67428]
#
# Id: 67146
# Injected into: [67428]
#
# Id: 67293
# Injected into: [67350]
#
# Id: 67307
# Injected into: [67319]
#
# Id: 67311
# Injected into: [67319]
#
# Id: 67643
# Injected into: [67676]
#
# Id: 67647
# Injected into: [67676]
#
# Id: 67659
# Injected into: [125651]
#
# Id: 67663
# Injected into: [125651]
#
# Id: 67961
# Injected into: [51490]
#
# Id: 67997
# Injected into: [51490]
#
# Id: 68267
# Injected into: [168166]
#
# Id: 68369
# Injected into: [1727]
#
# Id: 68410
# Injected into: [1727]
#
# Id: 68694
# Injected into: [51490]
#
# Id: 69118
# Injected into: [51490]
#
# Id: 69127
# Injected into: [51490]
#
# Id: 72286
# Injected into: [1709]
#
# Id: 72354
# Injected into: [1709]
#
# Id: 72679
# Injected into: [72810]
#
# Id: 72690
# Injected into: [72810]
#
# Id: 72700
# Injected into: [72810]
#
# Id: 84226
# Injected into: [1511]
#
# Id: 84231
# Injected into: [1511]
#
# Id: 84237
# Injected into: [1511]
#
# Id: 90859
# Injected into: [1803]
#
# Id: 91178
# Injected into: [1803]
#
# Id: 101625
# Injected into: [1715]
#
# Id: 102207
# Injected into: [1715]
#
# Id: 102210
# Injected into: [1715]
#
# Id: 102217
# Injected into: [1715]
#
# Id: 102302
# Injected into: [1715]
#
# Id: 102307
# Injected into: [1715]
#
# Id: 105736
# Injected into: [105729]
#
# Id: 105745
# Injected into: [105729]
#
# Id: 115501
# Injected into: [116206]
#
# Id: 115507
# Injected into: [116206]
#
# Id: 115515
# Injected into: [116206]
#
# Id: 121967
# Injected into: [124596]
#
# Id: 123249
# Injected into: [67350]
#
# Id: 123702
# Injected into: [67375]
#
# Id: 123704
# Injected into: [67375]
#
# Id: 123707
# Injected into: [67375]
#
# Id: 123712
# Injected into: [67375]
#
# Id: 123881
# Injected into: [51557]
#
# Id: 123885
# Injected into: [51557, 124596]
#
# Id: 124952
# Injected into: [124596]
#
# Id: 124955
# Injected into: [124596]
#
# Id: 124964
# Injected into: [124596]
#
# Id: 124967
# Injected into: [124596]
#
# Id: 124970
# Injected into: [124596]
#
# Id: 125027
# Injected into: [124596]
#
# Id: 125029
# Injected into: [124596]
#
# Id: 125626
# Injected into: [125646]
#
# Id: 125628
# Injected into: [125646]
#
# Id: 125685
# Injected into: [125646]
#
# Id: 125699
# Injected into: [67676]
#
# Id: 125722
# Injected into: [67676]
#
# Id: 125748
# Injected into: [125651]
#
# Id: 126887
# Injected into: [126865]
#
# Id: 126891
# Injected into: [126865]
#
# Id: 126907
# Injected into: [126868]
#
# Id: 126914
# Injected into: [126868]
#
# Id: 126979
# Injected into: [126862]
#
# Id: 135891
# Injected into: [187200]
#
# Id: 141958
# Injected into: [140332]
#
# Id: 143646
# Injected into: [1511]
#
# Id: 143648
# Injected into: [1511]
#
# Id: 143671
# Injected into: [1511]
#
# Id: 143672
# Injected into: [1511]
#
# Id: 171632
# Injected into: [170872]
#
# Id: 171633
# Injected into: [171955]
#
# Id: 171951
# Injected into: [171955]
#
# Id: 171985
# Injected into: [195305]
#
# Id: 180159
# Injected into: [178258]
#
# Id: 180712
# Injected into: [178261, 178261]
#
# Id: 180720
# Injected into: [178261]
#
# Id: 190605
# Injected into: [192065]
#
# Id: 191130
# Injected into: [190971]
#
# Id: 191137
# Injected into: [191142]
#
# Id: 192069
# Injected into: [192065]
#
# Id: 192248
# Injected into: [192199]
