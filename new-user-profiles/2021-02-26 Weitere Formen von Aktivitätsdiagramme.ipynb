# %% [markdown]
# # Basic idea

# %%
import math

from IPython.display import display, HTML, Markdown

def create_square_svg(a, color="#1E65A7"):
    result = []
    
    result.append('<svg style="width: 100%;" viewBox="0 0 100 100">')
    
    result.append("""
        <rect width="100" height="100" x="0" y="0" fill="#eee"/>
    """)
    y = 100-a
    
    result.append("""
        <rect width="%s" height="%s" x="0" y="%s" fill="%s"/>
    """ % (a, a, y, color))
    
    result.append('</svg>')
    
    return "\n".join(result)
    
display(HTML(create_square_svg(50)))
# Out:
# <svg style="width: 100%;" viewBox="0 0 100 100">
#
#         <rect width="100" height="100" x="0" y="0" fill="#eee"/>
#
#
#         <rect width="50" height="50" x="0" y="50" fill="#1E65A7"/>
#
# </svg>

# %%
specs = [
    {"color": "#1E65A7", "actions": 8078, "kind": "Bearbeitungen"},
    {"color": "#F1CD04", "actions": 567, "kind": "Kommentare"},
    {"color": "#00743F", "actions": 2498, "kind": "Reviewing"},
    {"color": "#D87A00", "actions": 123, "kind": "Themenbaum"},
]

def create_square(specs, max_actions=10000, svg_func=create_square_svg):
    result = []
    
    result.append("""
        <div style="width: 100%; display: flex; flex-flow: row wrap;
                    justify-content: space-around;">
    """)
    
    for spec in specs:
        result.append('<div style="width: 25%; min-width: 200px; padding: 1em;">')
        
        a = math.ceil(math.sqrt(min(spec["actions"], max_actions)))
        
        result.append(svg_func(a=a, color=spec["color"]))
        
        label = "%s ~ %a² %s" % (spec["actions"], a, spec["kind"])
        
        result.append('<p><b>%s</b></p>' % label)
        result.append('</div>')
    
    result.append("</div>")
        
    return "\n".join(result)    

display(Markdown("## Aktionen als Fläche darstellen"))
display(HTML(create_square(specs)))
# Out:
# ## Aktionen als Fläche darstellen
#         <div style="width: 100%; display: flex; flex-flow: row wrap;
#                     justify-content: space-around;">
#
# <div style="width: 25%; min-width: 200px; padding: 1em;">
# <svg style="width: 100%;" viewBox="0 0 100 100">
#
#         <rect width="100" height="100" x="0" y="0" fill="#eee"/>
#
#
#         <rect width="90" height="90" x="0" y="10" fill="#1E65A7"/>
#
# </svg>
# <p><b>8078 ~ 90² Bearbeitungen</b></p>
# </div>
# <div style="width: 25%; min-width: 200px; padding: 1em;">
# <svg style="width: 100%;" viewBox="0 0 100 100">
#
#         <rect width="100" height="100" x="0" y="0" fill="#eee"/>
#
#
#         <rect width="24" height="24" x="0" y="76" fill="#F1CD04"/>
#
# </svg>
# <p><b>567 ~ 24² Kommentare</b></p>
# </div>
# <div style="width: 25%; min-width: 200px; padding: 1em;">
# <svg style="width: 100%;" viewBox="0 0 100 100">
#
#         <rect width="100" height="100" x="0" y="0" fill="#eee"/>
#
#
#         <rect width="50" height="50" x="0" y="50" fill="#00743F"/>
#
# </svg>
# <p><b>2498 ~ 50² Reviewing</b></p>
# </div>
# <div style="width: 25%; min-width: 200px; padding: 1em;">
# <svg style="width: 100%;" viewBox="0 0 100 100">
#
#         <rect width="100" height="100" x="0" y="0" fill="#eee"/>
#
#
#         <rect width="12" height="12" x="0" y="88" fill="#D87A00"/>
#
# </svg>
# <p><b>123 ~ 12² Themenbaum</b></p>
# </div>
# </div>

# %% [markdown]
# # Jede Bearbeitung darstellen

# %%
def create_square_svg2(a, max_a=100, color="#1E65A7"):
    result = []
    
    single_box_length = 10
    total_length = single_box_length * max_a
    
    def create_circle(i, j, color, padding=2):
        x = i * single_box_length + single_box_length/2
        y = total_length - j * single_box_length - single_box_length/2
        r = (single_box_length-padding)/2
        
        result.append("""
            <circle cx="%s" cy="%s" fill="%s" r="%s" />
        """ % (x, y, color, r))
    
    def create_circles(a, color):
        for i in range(a):
            for j in range(a):
                create_circle(i, j, color)
    
    result.append("""
        <svg style="width: 100%%;" viewBox="0 0 %s %s">
    """ % (total_length, total_length))
    
    create_circles(max_a, "#eee")
    create_circles(a, color)
    
    result.append('</svg>')
    
    return "\n".join(result)
    
display(HTML(create_square_svg2(50)))
# Out:
#         <svg style="width: 100%;" viewBox="0 0 1000 1000">
#
#
#             <circle cx="5.0" cy="995.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="985.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="975.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="965.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="955.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="945.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="935.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="925.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="915.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="905.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="895.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="885.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="875.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="865.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="855.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="845.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="835.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="825.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="815.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="805.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="795.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="785.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="775.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="765.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="755.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="745.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="735.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="725.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="715.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="705.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="695.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="685.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="675.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="665.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="655.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="645.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="635.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="625.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="615.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="605.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="595.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="585.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="575.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="565.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="555.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="545.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="535.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="525.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="515.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="505.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="495.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="485.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="475.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="465.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="455.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="445.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="435.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="425.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="415.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="405.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="395.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="385.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="375.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="365.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="355.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="345.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="335.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="325.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="315.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="305.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="295.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="285.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="275.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="265.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="255.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="245.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="235.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="225.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="215.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="205.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="195.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="185.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="175.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="165.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="155.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="145.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="135.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="125.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="115.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="105.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="95.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="85.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="75.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="65.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="55.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="45.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="35.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="25.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="15.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="5.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="15.0" cy="995.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="15.0" cy="985.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="15.0" cy="975.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="15.0" cy="965.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="15.0" cy="955.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="15.0" cy="945.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="15.0" cy="935.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="15.0" cy="925.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="15.0" cy="915.0" fill="#eee"

# %% [markdown]
# ## Kleine Größe

# %%
#display(HTML(create_square(specs, svg_func=create_square_svg2)))
display(HTML('<div style="width: 250px">' + create_square_svg2(50) + '</div>'))
# Out:
# <div style="width: 250px">
#         <svg style="width: 100%;" viewBox="0 0 1000 1000">
#
#
#             <circle cx="5.0" cy="995.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="985.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="975.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="965.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="955.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="945.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="935.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="925.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="915.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="905.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="895.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="885.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="875.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="865.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="855.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="845.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="835.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="825.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="815.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="805.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="795.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="785.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="775.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="765.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="755.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="745.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="735.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="725.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="715.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="705.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="695.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="685.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="675.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="665.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="655.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="645.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="635.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="625.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="615.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="605.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="595.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="585.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="575.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="565.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="555.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="545.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="535.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="525.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="515.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="505.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="495.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="485.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="475.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="465.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="455.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="445.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="435.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="425.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="415.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="405.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="395.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="385.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="375.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="365.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="355.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="345.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="335.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="325.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="315.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="305.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="295.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="285.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="275.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="265.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="255.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="245.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="235.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="225.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="215.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="205.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="195.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="185.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="175.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="165.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="155.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="145.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="135.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="125.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="115.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="105.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="95.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="85.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="75.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="65.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="55.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="45.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="35.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="25.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="15.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="5.0" cy="5.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="15.0" cy="995.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="15.0" cy="985.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="15.0" cy="975.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="15.0" cy="965.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="15.0" cy="955.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="15.0" cy="945.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="15.0" cy="935.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="15.0" cy="925.0" fill="#eee" r="4.0" />
#
#
#             <circle cx="15.

# %% [markdown]
# # Idea: Show number of levels
#
# Icons from fontawesome: https://fontawesome.com/ ([License](https://fontawesome.com/license))

# %%
import uuid

from itertools import product, count

pen_icon="""
<svg  viewBox="0 0 512 512"><path d="M290.74 93.24l128.02 128.02-277.99 277.99-114.14 12.6C11.35 513.54-1.56 500.62.14 485.34l12.7-114.22 277.9-277.88zm207.2-19.06l-60.11-60.11c-18.75-18.75-49.16-18.75-67.91 0l-56.55 56.55 128.02 128.02 56.55-56.55c18.75-18.76 18.75-49.16 0-67.91z"></path></svg>
"""


def draw(no_icons, max_icons=100, icon=pen_icon, icon_width=100,
         color="#1E65A7",
         grey_color="#eee", padding = 2):
    icon_width = 20
    a = math.floor(math.sqrt(no_icons))
    a_max = math.floor(math.sqrt(max_icons))
    total_width = icon_width * a_max
    
    result = []
    
    result.append("""
        <svg style="width: 100%%; max-width:400px;" viewBox="0 0 %s %s">
    """ % (total_width, total_width))
    
    icon_id = uuid.uuid4()
    result.append(icon.replace("<svg", "<symbol id='%s' " % icon_id).replace("</svg>", '</symbol>'))
    
    for (j, i), c in zip(product(range(a_max), range(a_max)), count()):
        x = i * icon_width + padding
        y = j * icon_width + padding
        w = icon_width - 2*padding
        cr = color if c < no_icons else grey_color
    
        result.append("""
            <use href="#%s" x="%s" y="%s" width="%s" height="%s" fill="%s" />
        """ % (icon_id, x, y, w, w, cr))
    result.append("</svg>")
    
    return "\n".join(result)

display(HTML(draw(56)))
# Out:
#         <svg style="width: 100%; max-width:400px;" viewBox="0 0 200 200">
#
#
# <symbol id='e2ae0a02-c0b3-4057-8ab3-4549280fbcd3'   viewBox="0 0 512 512"><path d="M290.74 93.24l128.02 128.02-277.99 277.99-114.14 12.6C11.35 513.54-1.56 500.62.14 485.34l12.7-114.22 277.9-277.88zm207.2-19.06l-60.11-60.11c-18.75-18.75-49.16-18.75-67.91 0l-56.55 56.55 128.02 128.02 56.55-56.55c18.75-18.76 18.75-49.16 0-67.91z"></path></symbol>
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="2" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="22" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="42" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="62" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="82" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="102" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="122" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="142" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="162" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="182" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="2" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="22" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="42" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="62" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="82" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="102" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="122" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="142" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="162" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="182" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="2" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="22" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="42" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="62" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="82" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="102" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="122" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="142" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="162" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="182" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="2" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="22" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="42" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="62" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="82" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="102" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="122" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="142" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="162" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="182" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="2" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="22" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="42" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="62" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="82" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="102" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="122" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="142" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="162" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="182" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="2" y="102" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="22" y="102" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="42" y="102" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="62" y="102" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="82" y="102" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="102" y="102" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="122" y="102" width="16" height="16" fill="#eee" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="142" y="102" width="16" height="16" fill="#eee" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="162" y="102" width="16" height="16" fill="#eee" />
#
#
#             <use href="#e2ae0a02-c0b3-4057-8ab3-4549280fbcd3" x="

# %%
icons = [
    pen_icon,
    """<svg viewBox="0 0 512 512"><path d="M256 32C114.6 32 0 125.1 0 240c0 49.6 21.4 95 57 130.7C44.5 421.1 2.7 466 2.2 466.5c-2.2 2.3-2.8 5.7-1.5 8.7S4.8 480 8 480c66.3 0 116-31.8 140.6-51.4 32.7 12.3 69 19.4 107.4 19.4 141.4 0 256-93.1 256-208S397.4 32 256 32z"></path></svg>""",
    """<svg aria-hidden="true" focusable="false" data-prefix="fas" data-icon="heart" class="svg-inline--fa fa-heart fa-w-16" role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 512 512"><path d="M462.3 62.6C407.5 15.9 326 24.3 275.7 76.2L256 96.5l-19.7-20.3C186.1 24.3 104.5 15.9 49.7 62.6c-62.8 53.6-66.1 149.8-9.9 207.9l193.5 199.8c12.5 12.9 32.8 12.9 45.3 0l193.5-199.8c56.3-58.1 53-154.3-9.8-207.9z"></path></svg>""",
    """<svg viewBox="0 0 384 512"><path d="M378.31 378.49L298.42 288h30.63c9.01 0 16.98-5 20.78-13.06 3.8-8.04 2.55-17.26-3.28-24.05L268.42 160h28.89c9.1 0 17.3-5.35 20.86-13.61 3.52-8.13 1.86-17.59-4.24-24.08L203.66 4.83c-6.03-6.45-17.28-6.45-23.32 0L70.06 122.31c-6.1 6.49-7.75 15.95-4.24 24.08C69.38 154.65 77.59 160 86.69 160h28.89l-78.14 90.91c-5.81 6.78-7.06 15.99-3.27 24.04C37.97 283 45.93 288 54.95 288h30.63L5.69 378.49c-6 6.79-7.36 16.09-3.56 24.26 3.75 8.05 12 13.25 21.01 13.25H160v24.45l-30.29 48.4c-5.32 10.64 2.42 23.16 14.31 23.16h95.96c11.89 0 19.63-12.52 14.31-23.16L224 440.45V416h136.86c9.01 0 17.26-5.2 21.01-13.25 3.8-8.17 2.44-17.47-3.56-24.26z"></path></svg>"""
]

def create_graph(specs, max_actions=10000):
    result = []
    
    result.append("""
        <div style="width: 100%; display: flex; flex-flow: row wrap;
                    justify-content: space-around;">
    """)
    
    for spec, ic in zip(specs, icons):
        result.append('<div style="width: 25%; min-width: 230px; padding: 1em;">')
        
        a = math.ceil(math.sqrt(min(spec["actions"], max_actions)))
        
        result.append(draw(a, color=spec["color"], icon=ic))
        
        label = "%s: %s ~ %a²" % (spec["kind"], spec["actions"], a)
        
        result.append('<p><b>%s</b></p>' % label)
        result.append('</div>')
    
    result.append("</div>")
        
    return "\n".join(result)    

display(Markdown("## Anzahl Levels darstellen"))
display(HTML(create_graph(specs)))
# Out:
# ## Anzahl Levels darstellen
#         <div style="width: 100%; display: flex; flex-flow: row wrap;
#                     justify-content: space-around;">
#
# <div style="width: 25%; min-width: 230px; padding: 1em;">
#
#         <svg style="width: 100%; max-width:400px;" viewBox="0 0 200 200">
#
#
# <symbol id='7e688bb1-bed9-428d-aa5c-a0550859ee2d'   viewBox="0 0 512 512"><path d="M290.74 93.24l128.02 128.02-277.99 277.99-114.14 12.6C11.35 513.54-1.56 500.62.14 485.34l12.7-114.22 277.9-277.88zm207.2-19.06l-60.11-60.11c-18.75-18.75-49.16-18.75-67.91 0l-56.55 56.55 128.02 128.02 56.55-56.55c18.75-18.76 18.75-49.16 0-67.91z"></path></symbol>
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="2" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="22" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="42" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="62" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="82" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="102" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="122" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="142" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="162" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="182" y="2" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="2" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="22" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="42" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="62" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="82" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="102" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="122" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="142" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="162" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="182" y="22" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="2" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="22" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="42" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="62" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="82" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="102" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="122" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="142" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="162" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="182" y="42" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="2" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="22" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="42" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="62" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="82" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="102" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="122" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="142" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="162" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="182" y="62" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="2" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="22" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="42" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="62" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="82" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="102" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="122" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="142" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="162" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="182" y="82" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="2" y="102" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="22" y="102" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="42" y="102" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="62" y="102" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="82" y="102" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="102" y="102" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="122" y="102" width="16" height="16" fill="#1E65A7" />
#
#
#             <use href="#7e688bb1-bed9-428d-aa5c-a0550859ee2d" x="142" y="102" width="16" height="16" fill="#1E65A7" />

# %% [markdown]
# # Icons flächig darstellen

# %%
pen2_icon = """
<svg
   viewBox="0 0 512 512">
  <path
     d="M 313.37,70.62 441.39,198.64 140.77,499.25 26.63,511.85 C 11.35,513.54 -1.56,500.62 0.14,485.34 l 12.7,-114.22 z m 184.57,3.56 -60.11,-60.11 c -18.75,-18.75 -49.16,-18.75 -67.91,0 l -56.55,56.55 128.02,128.02 56.55,-56.55 c 18.75,-18.76 18.75,-49.16 0,-67.91 z"
   />
</svg>
"""

def draw2(actions, max_actions=10000, icon=pen2_icon,
         color="#1E65A7",
         grey_color="#eee"):
    total_width = math.sqrt(max_actions)
    result = []
    
    result.append("""
        <svg style="width: 100%%; max-width:400px;" viewBox="0 0 %s %s">
    """ % (total_width, total_width))
    
    icon_id = uuid.uuid4()
    result.append(icon.replace("<svg", "<symbol id='%s' " % icon_id).replace("</svg>", '</symbol>'))
    
    result.append("""
        <use href="#%s" x="0" y="0" width="%s" height="%s" fill="%s" />
    """ % (icon_id, total_width, total_width, grey_color))
    
    r = math.floor(math.sqrt(min(max_actions,actions)))
    x = (total_width-r)/2
    y = (total_width-r)/2
    
    result.append("""
        <use href="#%s" x="%s" y="%s" width="%s" height="%s" fill="%s" />
    """ % (icon_id, x, y, r, r, color))
    
    result.append("</svg>")
    
    return "\n".join(result)

display(HTML(draw2(5600)))
# Out:
#         <svg style="width: 100%; max-width:400px;" viewBox="0 0 100.0 100.0">
#
#
# <symbol id='ed208e13-b57b-4cf1-9928-96f034f69425'
#    viewBox="0 0 512 512">
#   <path
#      d="M 313.37,70.62 441.39,198.64 140.77,499.25 26.63,511.85 C 11.35,513.54 -1.56,500.62 0.14,485.34 l 12.7,-114.22 z m 184.57,3.56 -60.11,-60.11 c -18.75,-18.75 -49.16,-18.75 -67.91,0 l -56.55,56.55 128.02,128.02 56.55,-56.55 c 18.75,-18.76 18.75,-49.16 0,-67.91 z"
#    />
# </symbol>
#
#
#         <use href="#ed208e13-b57b-4cf1-9928-96f034f69425" x="0" y="0" width="100.0" height="100.0" fill="#eee" />
#
#
#         <use href="#ed208e13-b57b-4cf1-9928-96f034f69425" x="13.0" y="13.0" width="74" height="74" fill="#1E65A7" />
#
# </svg>

# %%
icons2 = list(icons)
icons2[0] = pen2_icon

def create_graph2(specs, max_actions=10000, grey_color="#eee"):
    result = []
    
    result.append("""
        <div style="width: 100%; display: flex; flex-flow: row wrap;
                    justify-content: space-around;">
    """)
    
    for spec, ic in zip(specs, icons2):
        result.append('<div style="width: 25%; min-width: 230px; padding: 1em;">')
        
        result.append(draw2(spec["actions"], color=spec["color"], icon=ic, grey_color=grey_color))
        
        label = "%s %s" % (spec["actions"], spec["kind"])
        
        result.append('<p><b>%s</b></p>' % label)
        result.append('</div>')
    
    result.append("</div>")
        
    return "\n".join(result)    

display(Markdown("## Icons flächig"))
display(HTML(create_graph2(specs)))
# Out:
# ## Icons flächig
#         <div style="width: 100%; display: flex; flex-flow: row wrap;
#                     justify-content: space-around;">
#
# <div style="width: 25%; min-width: 230px; padding: 1em;">
#
#         <svg style="width: 100%; max-width:400px;" viewBox="0 0 100.0 100.0">
#
#
# <symbol id='af5116f8-f4cb-4098-891c-a8823848bd5a'
#    viewBox="0 0 512 512">
#   <path
#      d="M 313.37,70.62 441.39,198.64 140.77,499.25 26.63,511.85 C 11.35,513.54 -1.56,500.62 0.14,485.34 l 12.7,-114.22 z m 184.57,3.56 -60.11,-60.11 c -18.75,-18.75 -49.16,-18.75 -67.91,0 l -56.55,56.55 128.02,128.02 56.55,-56.55 c 18.75,-18.76 18.75,-49.16 0,-67.91 z"
#    />
# </symbol>
#
#
#         <use href="#af5116f8-f4cb-4098-891c-a8823848bd5a" x="0" y="0" width="100.0" height="100.0" fill="#eee" />
#
#
#         <use href="#af5116f8-f4cb-4098-891c-a8823848bd5a" x="5.5" y="5.5" width="89" height="89" fill="#1E65A7" />
#
# </svg>
# <p><b>8078 Bearbeitungen</b></p>
# </div>
# <div style="width: 25%; min-width: 230px; padding: 1em;">
#
#         <svg style="width: 100%; max-width:400px;" viewBox="0 0 100.0 100.0">
#
# <symbol id='e84f6b49-7a34-4a48-bdf0-6f79c77aba50'  viewBox="0 0 512 512"><path d="M256 32C114.6 32 0 125.1 0 240c0 49.6 21.4 95 57 130.7C44.5 421.1 2.7 466 2.2 466.5c-2.2 2.3-2.8 5.7-1.5 8.7S4.8 480 8 480c66.3 0 116-31.8 140.6-51.4 32.7 12.3 69 19.4 107.4 19.4 141.4 0 256-93.1 256-208S397.4 32 256 32z"></path></symbol>
#
#         <use href="#e84f6b49-7a34-4a48-bdf0-6f79c77aba50" x="0" y="0" width="100.0" height="100.0" fill="#eee" />
#
#
#         <use href="#e84f6b49-7a34-4a48-bdf0-6f79c77aba50" x="38.5" y="38.5" width="23" height="23" fill="#F1CD04" />
#
# </svg>
# <p><b>567 Kommentare</b></p>
# </div>
# <div style="width: 25%; min-width: 230px; padding: 1em;">
#
#         <svg style="width: 100%; max-width:400px;" viewBox="0 0 100.0 100.0">
#
# <symbol id='f60379a6-d53f-40cc-accd-4dcf9e56225d'  aria-hidden="true" focusable="false" data-prefix="fas" data-icon="heart" class="svg-inline--fa fa-heart fa-w-16" role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 512 512"><path d="M462.3 62.6C407.5 15.9 326 24.3 275.7 76.2L256 96.5l-19.7-20.3C186.1 24.3 104.5 15.9 49.7 62.6c-62.8 53.6-66.1 149.8-9.9 207.9l193.5 199.8c12.5 12.9 32.8 12.9 45.3 0l193.5-199.8c56.3-58.1 53-154.3-9.8-207.9z"></path></symbol>
#
#         <use href="#f60379a6-d53f-40cc-accd-4dcf9e56225d" x="0" y="0" width="100.0" height="100.0" fill="#eee" />
#
#
#         <use href="#f60379a6-d53f-40cc-accd-4dcf9e56225d" x="25.5" y="25.5" width="49" height="49" fill="#00743F" />
#
# </svg>
# <p><b>2498 Reviewing</b></p>
# </div>
# <div style="width: 25%; min-width: 230px; padding: 1em;">
#
#         <svg style="width: 100%; max-width:400px;" viewBox="0 0 100.0 100.0">
#
# <symbol id='6957064c-6797-4837-8193-8ad65ec78891'  viewBox="0 0 384 512"><path d="M378.31 378.49L298.42 288h30.63c9.01 0 16.98-5 20.78-13.06 3.8-8.04 2.55-17.26-3.28-24.05L268.42 160h28.89c9.1 0 17.3-5.35 20.86-13.61 3.52-8.13 1.86-17.59-4.24-24.08L203.66 4.83c-6.03-6.45-17.28-6.45-23.32 0L70.06 122.31c-6.1 6.49-7.75 15.95-4.24 24.08C69.38 154.65 77.59 160 86.69 160h28.89l-78.14 90.91c-5.81 6.78-7.06 15.99-3.27 24.04C37.97 283 45.93 288 54.95 288h30.63L5.69 378.49c-6 6.79-7.36 16.09-3.56 24.26 3.75 8.05 12 13.25 21.01 13.25H160v24.45l-30.29 48.4c-5.32 10.64 2.42 23.16 14.31 23.16h95.96c11.89 0 19.63-12.52 14.31-23.16L224 440.45V416h136.86c9.01 0 17.26-5.2 21.01-13.25 3.8-8.17 2.44-17.47-3.56-24.26z"></path></symbol>
#
#         <use href="#6957064c-6797-4837-8193-8ad65ec78891" x="0" y="0" width="100.0" height="100.0" fill="#eee" />
#
#
#         <use href="#6957064c-6797-4837-8193-8ad65ec78891" x="44.5" y="44.5" width="11" height="11" fill="#D87A00" />
#
# </svg>
# <p><b>123 Themenbaum</b></p>
# </div>
# </div>

# %%
display(Markdown("## Icons flächig ohne Angabe Gesamtgröße"))
display(HTML(create_graph2(specs, grey_color="white")))
# Out:
# ## Icons flächig ohne Angabe Gesamtgröße
#         <div style="width: 100%; display: flex; flex-flow: row wrap;
#                     justify-content: space-around;">
#
# <div style="width: 25%; min-width: 230px; padding: 1em;">
#
#         <svg style="width: 100%; max-width:400px;" viewBox="0 0 100.0 100.0">
#
#
# <symbol id='f1424426-3152-4d2f-9a5e-c7104b0e3e6e'
#    viewBox="0 0 512 512">
#   <path
#      d="M 313.37,70.62 441.39,198.64 140.77,499.25 26.63,511.85 C 11.35,513.54 -1.56,500.62 0.14,485.34 l 12.7,-114.22 z m 184.57,3.56 -60.11,-60.11 c -18.75,-18.75 -49.16,-18.75 -67.91,0 l -56.55,56.55 128.02,128.02 56.55,-56.55 c 18.75,-18.76 18.75,-49.16 0,-67.91 z"
#    />
# </symbol>
#
#
#         <use href="#f1424426-3152-4d2f-9a5e-c7104b0e3e6e" x="0" y="0" width="100.0" height="100.0" fill="white" />
#
#
#         <use href="#f1424426-3152-4d2f-9a5e-c7104b0e3e6e" x="5.5" y="5.5" width="89" height="89" fill="#1E65A7" />
#
# </svg>
# <p><b>8078 Bearbeitungen</b></p>
# </div>
# <div style="width: 25%; min-width: 230px; padding: 1em;">
#
#         <svg style="width: 100%; max-width:400px;" viewBox="0 0 100.0 100.0">
#
# <symbol id='3973cf37-646d-4fe5-9f6b-9a9f19dfa070'  viewBox="0 0 512 512"><path d="M256 32C114.6 32 0 125.1 0 240c0 49.6 21.4 95 57 130.7C44.5 421.1 2.7 466 2.2 466.5c-2.2 2.3-2.8 5.7-1.5 8.7S4.8 480 8 480c66.3 0 116-31.8 140.6-51.4 32.7 12.3 69 19.4 107.4 19.4 141.4 0 256-93.1 256-208S397.4 32 256 32z"></path></symbol>
#
#         <use href="#3973cf37-646d-4fe5-9f6b-9a9f19dfa070" x="0" y="0" width="100.0" height="100.0" fill="white" />
#
#
#         <use href="#3973cf37-646d-4fe5-9f6b-9a9f19dfa070" x="38.5" y="38.5" width="23" height="23" fill="#F1CD04" />
#
# </svg>
# <p><b>567 Kommentare</b></p>
# </div>
# <div style="width: 25%; min-width: 230px; padding: 1em;">
#
#         <svg style="width: 100%; max-width:400px;" viewBox="0 0 100.0 100.0">
#
# <symbol id='c95ba661-4a79-41aa-860d-1cda390b5654'  aria-hidden="true" focusable="false" data-prefix="fas" data-icon="heart" class="svg-inline--fa fa-heart fa-w-16" role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 512 512"><path d="M462.3 62.6C407.5 15.9 326 24.3 275.7 76.2L256 96.5l-19.7-20.3C186.1 24.3 104.5 15.9 49.7 62.6c-62.8 53.6-66.1 149.8-9.9 207.9l193.5 199.8c12.5 12.9 32.8 12.9 45.3 0l193.5-199.8c56.3-58.1 53-154.3-9.8-207.9z"></path></symbol>
#
#         <use href="#c95ba661-4a79-41aa-860d-1cda390b5654" x="0" y="0" width="100.0" height="100.0" fill="white" />
#
#
#         <use href="#c95ba661-4a79-41aa-860d-1cda390b5654" x="25.5" y="25.5" width="49" height="49" fill="#00743F" />
#
# </svg>
# <p><b>2498 Reviewing</b></p>
# </div>
# <div style="width: 25%; min-width: 230px; padding: 1em;">
#
#         <svg style="width: 100%; max-width:400px;" viewBox="0 0 100.0 100.0">
#
# <symbol id='0828e6ad-1330-45b3-8b54-821a47718941'  viewBox="0 0 384 512"><path d="M378.31 378.49L298.42 288h30.63c9.01 0 16.98-5 20.78-13.06 3.8-8.04 2.55-17.26-3.28-24.05L268.42 160h28.89c9.1 0 17.3-5.35 20.86-13.61 3.52-8.13 1.86-17.59-4.24-24.08L203.66 4.83c-6.03-6.45-17.28-6.45-23.32 0L70.06 122.31c-6.1 6.49-7.75 15.95-4.24 24.08C69.38 154.65 77.59 160 86.69 160h28.89l-78.14 90.91c-5.81 6.78-7.06 15.99-3.27 24.04C37.97 283 45.93 288 54.95 288h30.63L5.69 378.49c-6 6.79-7.36 16.09-3.56 24.26 3.75 8.05 12 13.25 21.01 13.25H160v24.45l-30.29 48.4c-5.32 10.64 2.42 23.16 14.31 23.16h95.96c11.89 0 19.63-12.52 14.31-23.16L224 440.45V416h136.86c9.01 0 17.26-5.2 21.01-13.25 3.8-8.17 2.44-17.47-3.56-24.26z"></path></symbol>
#
#         <use href="#0828e6ad-1330-45b3-8b54-821a47718941" x="0" y="0" width="100.0" height="100.0" fill="white" />
#
#
#         <use href="#0828e6ad-1330-45b3-8b54-821a47718941" x="44.5" y="44.5" width="11" height="11" fill="#D87A00" />
#
# </svg>
# <p><b>123 Themenbaum</b></p>
# </div>
# </div>

# %%
def draw3(actions, kind="Verbesserungen am Inhalt", max_actions=10000, color="#1E65A7", icon=pen_icon,
          width=100, line_height=4, grey="#ccc", text_size=6,
          space_lines=30, rect_height=5, rect_width=60, padding=5):
    result = []
    
    result.append('<div style="width: 25%; min-width:250px;">')
    result.append("<p style='text-align: center;'><b>%sx %s</b></p>" % (actions, kind))
    
    height = width+line_height+padding+2*text_size+space_lines+rect_height+2
    result.append('<svg viewBox="0 0 %s %s" style="width: 100%%; padding-top: 10px;">' % (width, height))
    
    icon_id = uuid.uuid4()
    result.append(icon.replace("<svg", "<symbol id='%s' " % icon_id).replace("</svg>", '</symbol>'))
    result.append('<defs>')
    result.append("""
        <marker id="end" markerWidth="5" markerHeight="4"
                refX="5" refY="2" orient="auto">
            <line x1="0" y1="0" x2="5" y2="2" stroke="black"/>
            <line x1="5" y1="2" x2="0" y2="4" stroke="black"/>
        </marker>
        <marker id="start" markerWidth="5" markerHeight="4"
                refX="0" refY="2" orient="auto">
            <line x1="5" y1="0" x2="0" y2="2" stroke="black"/>
            <line x1="0" y1="2" x2="5" y2="4" stroke="black"/>
        </marker>
    """)
    result.append('</defs>')
    
    r = math.floor(math.sqrt(min(actions, max_actions)))
    
    x = (width-r)/2
    y = (width-r)/2
    
    #result.append("""
    #    <use href="#%s" x="%s" y="%s" width="%s" height="%s" fill="%s" />
    #""" % (icon_id, 0, 0, width, width, grey))
    result.append("""
        <use href="#%s" x="%s" y="%s" width="%s" height="%s" fill="%s" />
    """ % (icon_id, x, y, r, r, color))
    
    x_line = x
    y_line = width + line_height/2
    x2 = x+r
    
    x_rect = (width-rect_width)/2
    y_rect = y_line + space_lines
    result.append("""
        <rect x="%s" y="%s" fill="%s" width="%s" height="%s" rx="2" ry="2" />
    """ % (x_rect, y_rect, grey, rect_width, rect_height))
    
    progress = math.sqrt(min(actions, max_actions)) - r
    result.append("""
        <rect x="%s" y="%s" fill="%s" width="%s" height="%s" rx="2" ry="2" />
    """ % (x_rect, y_rect, color, rect_width*progress, rect_height))
    
    result.append("""
        <text x="%s" y="%s" style="font-size: %spx" text-anchor="middle">%s</text>
    """ % (x_rect, y_rect+rect_height+text_size, text_size, r))
    result.append("""
        <text x="%s" y="%s" style="font-size: %spx" text-anchor="middle">%s</text>
    """ % (x_rect+rect_width, y_rect+rect_height+text_size, text_size, r+1))
    
    x_rect2 = x_rect-padding
    y_rect2 = y_rect-padding
    rect2_width = rect_width + 2*padding
    
    result.append("""
        <rect x="%s" y="%s" width="%s" height="%s" fill="none" stroke="%s" stroke-width="1" />
    """ % (x_rect2, y_rect2, rect2_width,
           rect_height+2*padding+text_size, grey))
    
    r_small=5
    x_small = x_line+r-r_small/2
    y_small = y_line-r_small/2
    
    result.append("""
        <rect x="%s" y="%s" width="%s" height="%s" fill="none" stroke="%s" stroke-width="1" />
    """ % (x_small, y_small, r_small, r_small, grey))
    
    result.append("""
        <line x1="%s" y1="%s" x2="%s" y2="%s" stroke="%s" stroke-width="1" />
    """ %(x_small, y_small+r_small, x_rect2, y_rect2, grey))
    result.append("""
        <line x1="%s" y1="%s" x2="%s" y2="%s" stroke="%s" stroke-width="1" />
    """ %(x_small+r_small, y_small+r_small, x_rect2+rect2_width, y_rect2, grey))
    
    
    result.append("""
        <line x1="%s" y1="%s" x2="%s" y2="%s" stroke="black"
              style="marker-end: url(#end); marker-start: url(#start)"/>
    """ %(x,y_line,x2,y_line))
    result.append("""
        <text x="%s" y="%s" style="font-size: %spx" text-anchor="middle">%s</text>
    """ % (x+r/2, y_line-text_size, text_size, r))
    
    result.append('</svg>')
    result.append('</div>')
    
    return "\n".join(result)

display(HTML(draw3(2475)))
# Out:
# <div style="width: 25%; min-width:250px;">
# <p style='text-align: center;'><b>2475x Verbesserungen am Inhalt</b></p>
# <svg viewBox="0 0 100 158" style="width: 100%; padding-top: 10px;">
#
# <symbol id='691a60ed-7fe7-4361-aeb1-33f793d59765'   viewBox="0 0 512 512"><path d="M290.74 93.24l128.02 128.02-277.99 277.99-114.14 12.6C11.35 513.54-1.56 500.62.14 485.34l12.7-114.22 277.9-277.88zm207.2-19.06l-60.11-60.11c-18.75-18.75-49.16-18.75-67.91 0l-56.55 56.55 128.02 128.02 56.55-56.55c18.75-18.76 18.75-49.16 0-67.91z"></path></symbol>
#
# <defs>
#
#         <marker id="end" markerWidth="5" markerHeight="4"
#                 refX="5" refY="2" orient="auto">
#             <line x1="0" y1="0" x2="5" y2="2" stroke="black"/>
#             <line x1="5" y1="2" x2="0" y2="4" stroke="black"/>
#         </marker>
#         <marker id="start" markerWidth="5" markerHeight="4"
#                 refX="0" refY="2" orient="auto">
#             <line x1="5" y1="0" x2="0" y2="2" stroke="black"/>
#             <line x1="0" y1="2" x2="5" y2="4" stroke="black"/>
#         </marker>
#
# </defs>
#
#         <use href="#691a60ed-7fe7-4361-aeb1-33f793d59765" x="25.5" y="25.5" width="49" height="49" fill="#1E65A7" />
#
#
#         <rect x="20.0" y="132.0" fill="#ccc" width="60" height="5" rx="2" ry="2" />
#
#
#         <rect x="20.0" y="132.0" fill="#1E65A7" width="44.962311319859936" height="5" rx="2" ry="2" />
#
#
#         <text x="20.0" y="143.0" style="font-size: 6px" text-anchor="middle">49</text>
#
#
#         <text x="80.0" y="143.0" style="font-size: 6px" text-anchor="middle">50</text>
#
#
#         <rect x="15.0" y="127.0" width="70" height="21" fill="none" stroke="#ccc" stroke-width="1" />
#
#
#         <rect x="72.0" y="99.5" width="5" height="5" fill="none" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="72.0" y1="104.5" x2="15.0" y2="127.0" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="77.0" y1="104.5" x2="85.0" y2="127.0" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="25.5" y1="102.0" x2="74.5" y2="102.0" stroke="black"
#               style="marker-end: url(#end); marker-start: url(#start)"/>
#
#
#         <text x="50.0" y="96.0" style="font-size: 6px" text-anchor="middle">49</text>
#
# </svg>
# </div>

# %%
def create_graph3(specs, draw_func=draw3, icons=icons):
    result = []
    
    result.append("""
        <div style="width: 100%; display: flex; flex-flow: row wrap;
                    justify-content: space-around;">
    """)
    
    for spec, ic in zip(specs, icons):
        result.append('<div style="width: 25%; min-width: 230px; padding: 2em;">')
        
        result.append(draw_func(spec["actions"], color=spec["color"], kind=spec["kind"], icon=ic))
        
        #label = "%s %s" % (spec["actions"], spec["kind"])
        
        #result.append('<p><b>%s</b></p>' % label)
        result.append('</div>')
    
    result.append("</div>")
        
    return "\n".join(result)    

display(Markdown("## Weitere Variante"))
display(HTML(create_graph3(specs)))
# Out:
# ## Weitere Variante
#         <div style="width: 100%; display: flex; flex-flow: row wrap;
#                     justify-content: space-around;">
#
# <div style="width: 25%; min-width: 230px; padding: 2em;">
# <div style="width: 25%; min-width:250px;">
# <p style='text-align: center;'><b>8078x Bearbeitungen</b></p>
# <svg viewBox="0 0 100 158" style="width: 100%; padding-top: 10px;">
#
# <symbol id='34c002fc-6116-4c4f-8731-d94d920b3d83'   viewBox="0 0 512 512"><path d="M290.74 93.24l128.02 128.02-277.99 277.99-114.14 12.6C11.35 513.54-1.56 500.62.14 485.34l12.7-114.22 277.9-277.88zm207.2-19.06l-60.11-60.11c-18.75-18.75-49.16-18.75-67.91 0l-56.55 56.55 128.02 128.02 56.55-56.55c18.75-18.76 18.75-49.16 0-67.91z"></path></symbol>
#
# <defs>
#
#         <marker id="end" markerWidth="5" markerHeight="4"
#                 refX="5" refY="2" orient="auto">
#             <line x1="0" y1="0" x2="5" y2="2" stroke="black"/>
#             <line x1="5" y1="2" x2="0" y2="4" stroke="black"/>
#         </marker>
#         <marker id="start" markerWidth="5" markerHeight="4"
#                 refX="0" refY="2" orient="auto">
#             <line x1="5" y1="0" x2="0" y2="2" stroke="black"/>
#             <line x1="0" y1="2" x2="5" y2="4" stroke="black"/>
#         </marker>
#
# </defs>
#
#         <use href="#34c002fc-6116-4c4f-8731-d94d920b3d83" x="5.5" y="5.5" width="89" height="89" fill="#1E65A7" />
#
#
#         <rect x="20.0" y="132.0" fill="#ccc" width="60" height="5" rx="2" ry="2" />
#
#
#         <rect x="20.0" y="132.0" fill="#1E65A7" width="52.661680469117016" height="5" rx="2" ry="2" />
#
#
#         <text x="20.0" y="143.0" style="font-size: 6px" text-anchor="middle">89</text>
#
#
#         <text x="80.0" y="143.0" style="font-size: 6px" text-anchor="middle">90</text>
#
#
#         <rect x="15.0" y="127.0" width="70" height="21" fill="none" stroke="#ccc" stroke-width="1" />
#
#
#         <rect x="92.0" y="99.5" width="5" height="5" fill="none" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="92.0" y1="104.5" x2="15.0" y2="127.0" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="97.0" y1="104.5" x2="85.0" y2="127.0" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="5.5" y1="102.0" x2="94.5" y2="102.0" stroke="black"
#               style="marker-end: url(#end); marker-start: url(#start)"/>
#
#
#         <text x="50.0" y="96.0" style="font-size: 6px" text-anchor="middle">89</text>
#
# </svg>
# </div>
# </div>
# <div style="width: 25%; min-width: 230px; padding: 2em;">
# <div style="width: 25%; min-width:250px;">
# <p style='text-align: center;'><b>567x Kommentare</b></p>
# <svg viewBox="0 0 100 158" style="width: 100%; padding-top: 10px;">
# <symbol id='9e0ed59e-933b-441d-a848-545f8222e7d3'  viewBox="0 0 512 512"><path d="M256 32C114.6 32 0 125.1 0 240c0 49.6 21.4 95 57 130.7C44.5 421.1 2.7 466 2.2 466.5c-2.2 2.3-2.8 5.7-1.5 8.7S4.8 480 8 480c66.3 0 116-31.8 140.6-51.4 32.7 12.3 69 19.4 107.4 19.4 141.4 0 256-93.1 256-208S397.4 32 256 32z"></path></symbol>
# <defs>
#
#         <marker id="end" markerWidth="5" markerHeight="4"
#                 refX="5" refY="2" orient="auto">
#             <line x1="0" y1="0" x2="5" y2="2" stroke="black"/>
#             <line x1="5" y1="2" x2="0" y2="4" stroke="black"/>
#         </marker>
#         <marker id="start" markerWidth="5" markerHeight="4"
#                 refX="0" refY="2" orient="auto">
#             <line x1="5" y1="0" x2="0" y2="2" stroke="black"/>
#             <line x1="0" y1="2" x2="5" y2="4" stroke="black"/>
#         </marker>
#
# </defs>
#
#         <use href="#9e0ed59e-933b-441d-a848-545f8222e7d3" x="38.5" y="38.5" width="23" height="23" fill="#F1CD04" />
#
#
#         <rect x="20.0" y="132.0" fill="#ccc" width="60" height="5" rx="2" ry="2" />
#
#
#         <rect x="20.0" y="132.0" fill="#F1CD04" width="48.70570797487893" height="5" rx="2" ry="2" />
#
#
#         <text x="20.0" y="143.0" style="font-size: 6px" text-anchor="middle">23</text>
#
#
#         <text x="80.0" y="143.0" style="font-size: 6px" text-anchor="middle">24</text>
#
#
#         <rect x="15.0" y="127.0" width="70" height="21" fill="none" stroke="#ccc" stroke-width="1" />
#
#
#         <rect x="59.0" y="99.5" width="5" height="5" fill="none" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="59.0" y1="104.5" x2="15.0" y2="127.0" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="64.0" y1="104.5" x2="85.0" y2="127.0" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="38.5" y1="102.0" x2="61.5" y2="102.0" stroke="black"
#               style="marker-end: url(#end); marker-start: url(#start)"/>
#
#
#         <text x="50.0" y="96.0" style="font-size: 6px" text-anchor="middle">23</text>
#
# </svg>
# </div>
# </div>
# <div style="width: 25%; min-width: 230px; padding: 2em;">
# <div style="width: 25%; min-width:250px;">
# <p style='text-align: center;'><b>2498x Reviewing</b></p>
# <svg viewBox="0 0 100 158" style="width: 100%; padding-top: 10px;">
# <symbol id='d510924c-8957-4a99-8598-df624088dd4d'  aria-hidden="true" focusable="false" data-prefix="fas" data-icon="heart" class="svg-inline--fa fa-heart fa-w-16" role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 512 512"><path d="M462.3 62.6C407.5 15.9 326 24.3 275.7 76.2L256 96.5l-19.7-20.3C186.1 24.3 104.5 15.9 49.7 62.6c-62.8 53.6-66.1 149.8-9.9 207.9l193.5 199.8c12.5 12.9 32.8 12.9 45.3 0l193.5-199.8c56.3-58.1 53-154.3-9.8-207.9z"></path></symbol>
# <defs>
#
#         <marker id="end" markerWidth="5" markerHeight="4"
#                 refX="5" refY="2" orient="auto">
#             <line x1="0" y1="0" x2="5" y2="2" stroke="black"/>
#             <line x1="5" y1="2" x2="0" y2="4" stroke="black"/>
#         </marker>
#         <marker id="start" markerWidth="5" markerHeight="4"
#                 refX="0" refY="2" orient="auto">
#             <line x1="5" y1="0" x2="0" y2="2" stroke="black"/>
#             <line x1="0" y1="2" x2="5" y2="4" stroke="black"/>
#         </marker>
#
# </defs>
#
#         <use href="#d510924c-8957-4a99-8598-df624088dd4d" x="25.5" y="25.5" width="49" height="49" fill="#00743F" />
#
#
#         <rect x="20.0" y="132.0" fill="#ccc" width="60" height="5" rx="2" ry="2" />
#
#
#         <rect x="20.0" y="132.0" fill="#00743F" width="58.79975990395181" height="5" rx="2" ry="2" />
#
#
#         <text x="20.0" y="143.0" style="font-size: 6px" text-anchor="middle">49</text>
#
#
#         <text x="80.0" y="143.0" style="font-size: 6px" text-anchor="middle">50</text>
#
#
#         <rect x="15.0" y="127.0" width="70" height="21" fill="none" stroke="#ccc" stroke-width="1" />
#
#
#         <rect x="72.0" y="99.5" width="5" height="5" fill="none" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="72.0" y1="104.5" x2="15.0" y2="127.0" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="77.0" y1="104.5" x2="85.0" y2="127.0" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="25.5" y1="102.0" x2="74.5" y2="102.0" stroke="black"
#               style="marker-end: url(#end); marker-start: url(#start)"/>
#
#
#         <text x="50.0" y="96.0" style="font-size: 6px" text-anchor="middle">49</text>
#
# </svg>
# </div>
# </div>
# <div style="width: 25%; min-width: 230px; padding: 2em;">
# <div style="width: 25%; min-width:250px;">
# <p style='text-align: center;'><b>123x Themenbaum</b></p>
# <svg viewBox="0 0 100 158" style="width: 100%; padding-top: 10px;">
# <symbol id='b70fa44b-da2d-4dec-bbd5-2bc205ded388'  viewBox="0 0 384 512"><path d="M378.31 378.49L298.42 288h30.63c9.01 0 16.98-5 20.78-13.06 3.8-8.04 2.55-17.26-3.28-24.05L268.42 160h28.89c9.1 0 17.3-5.35 20.86-13.61 3.52-8.13 1.86-17.59-4.24-24.08L203.66 4.83c-6.03-6.45-17.28-6.45-23.32 0L70.06 122.31c-6.1 6.49-7.75 15.95-4.24 24.08C69.38 154.65 77.59 160 86.69 160h28.89l-78.14 90.91c-5.81 6.78-7.06 15.99-3.27 24.04C37.97 283 45.93 288 54.95 288h30.63L5.69 378.49c-6 6.79-7.36 16.09-3.56 24.26 3.75 8.05 12 13.25 21.01 13.25H160v24.45l-30.29 48.4c-5.32 10.64 2.42 23.16 14.31 23.16h95.96c11.89 0 19.63-12.52 14.31-23.16L224 440.45V416h136.86c9.01 0 17.26-5.2 21.01-13.25 3.8-8.17 2.44-17.47-3.56-24.26z"></path></symbol>

# %%
import numpy as np

def draw4(actions, kind="Verbesserungen am Inhalt", max_actions=10000, color="#1E65A7", icon=pen2_icon,
          width=100, line_height=4, grey="#ccc", text_size=6,
          space_lines=30, rect_height=5, rect_width=60, padding=5):
    result = []
    
    result.append('<div style="width: 25%; min-width:250px;">')
    result.append("<p style='text-align: center;'><b>%sx %s</b></p>" % (actions, kind))
    
    height = width+line_height+padding+2*text_size+space_lines+rect_height+12
    result.append('<svg viewBox="0 0 %s %s" style="width: 100%%; padding-top: 10px;">' % (width, height))
    
    icon_id = uuid.uuid4()
    result.append(icon.replace("<svg", "<symbol id='%s' " % icon_id).replace("</svg>", '</symbol>'))
    result.append('<defs>')
    result.append("""
        <marker id="end" markerWidth="5" markerHeight="4"
                refX="5" refY="2" orient="auto">
            <line x1="0" y1="0" x2="5" y2="2" stroke="black"/>
            <line x1="5" y1="2" x2="0" y2="4" stroke="black"/>
        </marker>
        <marker id="start" markerWidth="5" markerHeight="4"
                refX="0" refY="2" orient="auto">
            <line x1="5" y1="0" x2="0" y2="2" stroke="black"/>
            <line x1="0" y1="2" x2="5" y2="4" stroke="black"/>
        </marker>
    """)
    result.append('</defs>')
    
    greys = np.linspace(180, 256, 6)[:-1]
    for g, i in zip(np.flip(greys), count()):
        grey_width = width / len(greys) * (len(greys)-i)
        x = (width-grey_width) / 2
        y = (width-grey_width) / 2
    
        result.append("""
            <use href="#%s" x="%s" y="%s" width="%s" height="%s" fill="%s" />
        """ % (icon_id, x, y, grey_width, grey_width, "rgb(%s,%s,%s)" % (g,g,g)))
    
    r = math.floor(math.sqrt(min(actions, max_actions)))
    
    x = (width-r)/2
    y = (width-r)/2
    
    result.append("""
        <use href="#%s" x="%s" y="%s" width="%s" height="%s" fill="%s" />
    """ % (icon_id, x, y, r, r, color))
    
    x_line = x
    y_line = width + line_height/2+text_size+10
    x2 = x+r
    
    x_rect = (width-rect_width)/2
    y_rect = y_line + space_lines
    result.append("""
        <rect x="%s" y="%s" fill="%s" width="%s" height="%s" rx="2" ry="2" />
    """ % (x_rect, y_rect, grey, rect_width, rect_height))
    
    progress = math.sqrt(min(actions, max_actions)) - r
    result.append("""
        <rect x="%s" y="%s" fill="%s" width="%s" height="%s" rx="2" ry="2" />
    """ % (x_rect, y_rect, color, rect_width*progress, rect_height))
    
    result.append("""
        <text x="%s" y="%s" style="font-size: %spx" text-anchor="middle">%s</text>
    """ % (x_rect, y_rect+rect_height+text_size, text_size, r))
    result.append("""
        <text x="%s" y="%s" style="font-size: %spx" text-anchor="middle">%s</text>
    """ % (x_rect+rect_width, y_rect+rect_height+text_size, text_size, r+1))
    
    x_rect2 = x_rect-padding
    y_rect2 = y_rect-padding
    rect2_width = rect_width + 2*padding
    
    result.append("""
        <rect x="%s" y="%s" width="%s" height="%s" fill="none" stroke="%s" stroke-width="1" />
    """ % (x_rect2, y_rect2, rect2_width,
           rect_height+2*padding+text_size, grey))
    
    r_small=5
    x_small = x_line+r-r_small/2
    y_small = y_line-r_small/2
    
    result.append("""
        <rect x="%s" y="%s" width="%s" height="%s" fill="none" stroke="%s" stroke-width="1" />
    """ % (x_small, y_small, r_small, r_small, grey))
    
    result.append("""
        <line x1="%s" y1="%s" x2="%s" y2="%s" stroke="%s" stroke-width="1" />
    """ %(x_small, y_small+r_small, x_rect2, y_rect2, grey))
    result.append("""
        <line x1="%s" y1="%s" x2="%s" y2="%s" stroke="%s" stroke-width="1" />
    """ %(x_small+r_small, y_small+r_small, x_rect2+rect2_width, y_rect2, grey))
    
    
    result.append("""
        <line x1="%s" y1="%s" x2="%s" y2="%s" stroke="black"
              style="marker-end: url(#end); marker-start: url(#start)"/>
    """ %(x,y_line,x2,y_line))
    result.append("""
        <text x="%s" y="%s" style="font-size: %spx" text-anchor="middle">%s</text>
    """ % (x+r/2, y_line-text_size, text_size, r))
    
    result.append('</svg>')
    result.append('</div>')
    
    return "\n".join(result)

display(HTML(draw4(2475)))
# Out:
# <div style="width: 25%; min-width:250px;">
# <p style='text-align: center;'><b>2475x Verbesserungen am Inhalt</b></p>
# <svg viewBox="0 0 100 168" style="width: 100%; padding-top: 10px;">
#
# <symbol id='e4d7fca4-d877-4c01-8990-2d10763321f7'
#    viewBox="0 0 512 512">
#   <path
#      d="M 313.37,70.62 441.39,198.64 140.77,499.25 26.63,511.85 C 11.35,513.54 -1.56,500.62 0.14,485.34 l 12.7,-114.22 z m 184.57,3.56 -60.11,-60.11 c -18.75,-18.75 -49.16,-18.75 -67.91,0 l -56.55,56.55 128.02,128.02 56.55,-56.55 c 18.75,-18.76 18.75,-49.16 0,-67.91 z"
#    />
# </symbol>
#
# <defs>
#
#         <marker id="end" markerWidth="5" markerHeight="4"
#                 refX="5" refY="2" orient="auto">
#             <line x1="0" y1="0" x2="5" y2="2" stroke="black"/>
#             <line x1="5" y1="2" x2="0" y2="4" stroke="black"/>
#         </marker>
#         <marker id="start" markerWidth="5" markerHeight="4"
#                 refX="0" refY="2" orient="auto">
#             <line x1="5" y1="0" x2="0" y2="2" stroke="black"/>
#             <line x1="0" y1="2" x2="5" y2="4" stroke="black"/>
#         </marker>
#
# </defs>
#
#             <use href="#e4d7fca4-d877-4c01-8990-2d10763321f7" x="0.0" y="0.0" width="100.0" height="100.0" fill="rgb(240.8,240.8,240.8)" />
#
#
#             <use href="#e4d7fca4-d877-4c01-8990-2d10763321f7" x="10.0" y="10.0" width="80.0" height="80.0" fill="rgb(225.6,225.6,225.6)" />
#
#
#             <use href="#e4d7fca4-d877-4c01-8990-2d10763321f7" x="20.0" y="20.0" width="60.0" height="60.0" fill="rgb(210.4,210.4,210.4)" />
#
#
#             <use href="#e4d7fca4-d877-4c01-8990-2d10763321f7" x="30.0" y="30.0" width="40.0" height="40.0" fill="rgb(195.2,195.2,195.2)" />
#
#
#             <use href="#e4d7fca4-d877-4c01-8990-2d10763321f7" x="40.0" y="40.0" width="20.0" height="20.0" fill="rgb(180.0,180.0,180.0)" />
#
#
#         <use href="#e4d7fca4-d877-4c01-8990-2d10763321f7" x="25.5" y="25.5" width="49" height="49" fill="#1E65A7" />
#
#
#         <rect x="20.0" y="148.0" fill="#ccc" width="60" height="5" rx="2" ry="2" />
#
#
#         <rect x="20.0" y="148.0" fill="#1E65A7" width="44.962311319859936" height="5" rx="2" ry="2" />
#
#
#         <text x="20.0" y="159.0" style="font-size: 6px" text-anchor="middle">49</text>
#
#
#         <text x="80.0" y="159.0" style="font-size: 6px" text-anchor="middle">50</text>
#
#
#         <rect x="15.0" y="143.0" width="70" height="21" fill="none" stroke="#ccc" stroke-width="1" />
#
#
#         <rect x="72.0" y="115.5" width="5" height="5" fill="none" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="72.0" y1="120.5" x2="15.0" y2="143.0" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="77.0" y1="120.5" x2="85.0" y2="143.0" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="25.5" y1="118.0" x2="74.5" y2="118.0" stroke="black"
#               style="marker-end: url(#end); marker-start: url(#start)"/>
#
#
#         <text x="50.0" y="112.0" style="font-size: 6px" text-anchor="middle">49</text>
#
# </svg>
# </div>

# %%
display(Markdown("## Weitere Variante"))
display(HTML(create_graph3(specs, draw_func=draw4, icons=icons2)))
# Out:
# ## Weitere Variante
#         <div style="width: 100%; display: flex; flex-flow: row wrap;
#                     justify-content: space-around;">
#
# <div style="width: 25%; min-width: 230px; padding: 2em;">
# <div style="width: 25%; min-width:250px;">
# <p style='text-align: center;'><b>8078x Bearbeitungen</b></p>
# <svg viewBox="0 0 100 168" style="width: 100%; padding-top: 10px;">
#
# <symbol id='55272a89-9ba8-475b-9ded-dc06029e1827'
#    viewBox="0 0 512 512">
#   <path
#      d="M 313.37,70.62 441.39,198.64 140.77,499.25 26.63,511.85 C 11.35,513.54 -1.56,500.62 0.14,485.34 l 12.7,-114.22 z m 184.57,3.56 -60.11,-60.11 c -18.75,-18.75 -49.16,-18.75 -67.91,0 l -56.55,56.55 128.02,128.02 56.55,-56.55 c 18.75,-18.76 18.75,-49.16 0,-67.91 z"
#    />
# </symbol>
#
# <defs>
#
#         <marker id="end" markerWidth="5" markerHeight="4"
#                 refX="5" refY="2" orient="auto">
#             <line x1="0" y1="0" x2="5" y2="2" stroke="black"/>
#             <line x1="5" y1="2" x2="0" y2="4" stroke="black"/>
#         </marker>
#         <marker id="start" markerWidth="5" markerHeight="4"
#                 refX="0" refY="2" orient="auto">
#             <line x1="5" y1="0" x2="0" y2="2" stroke="black"/>
#             <line x1="0" y1="2" x2="5" y2="4" stroke="black"/>
#         </marker>
#
# </defs>
#
#             <use href="#55272a89-9ba8-475b-9ded-dc06029e1827" x="0.0" y="0.0" width="100.0" height="100.0" fill="rgb(240.8,240.8,240.8)" />
#
#
#             <use href="#55272a89-9ba8-475b-9ded-dc06029e1827" x="10.0" y="10.0" width="80.0" height="80.0" fill="rgb(225.6,225.6,225.6)" />
#
#
#             <use href="#55272a89-9ba8-475b-9ded-dc06029e1827" x="20.0" y="20.0" width="60.0" height="60.0" fill="rgb(210.4,210.4,210.4)" />
#
#
#             <use href="#55272a89-9ba8-475b-9ded-dc06029e1827" x="30.0" y="30.0" width="40.0" height="40.0" fill="rgb(195.2,195.2,195.2)" />
#
#
#             <use href="#55272a89-9ba8-475b-9ded-dc06029e1827" x="40.0" y="40.0" width="20.0" height="20.0" fill="rgb(180.0,180.0,180.0)" />
#
#
#         <use href="#55272a89-9ba8-475b-9ded-dc06029e1827" x="5.5" y="5.5" width="89" height="89" fill="#1E65A7" />
#
#
#         <rect x="20.0" y="148.0" fill="#ccc" width="60" height="5" rx="2" ry="2" />
#
#
#         <rect x="20.0" y="148.0" fill="#1E65A7" width="52.661680469117016" height="5" rx="2" ry="2" />
#
#
#         <text x="20.0" y="159.0" style="font-size: 6px" text-anchor="middle">89</text>
#
#
#         <text x="80.0" y="159.0" style="font-size: 6px" text-anchor="middle">90</text>
#
#
#         <rect x="15.0" y="143.0" width="70" height="21" fill="none" stroke="#ccc" stroke-width="1" />
#
#
#         <rect x="92.0" y="115.5" width="5" height="5" fill="none" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="92.0" y1="120.5" x2="15.0" y2="143.0" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="97.0" y1="120.5" x2="85.0" y2="143.0" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="5.5" y1="118.0" x2="94.5" y2="118.0" stroke="black"
#               style="marker-end: url(#end); marker-start: url(#start)"/>
#
#
#         <text x="50.0" y="112.0" style="font-size: 6px" text-anchor="middle">89</text>
#
# </svg>
# </div>
# </div>
# <div style="width: 25%; min-width: 230px; padding: 2em;">
# <div style="width: 25%; min-width:250px;">
# <p style='text-align: center;'><b>567x Kommentare</b></p>
# <svg viewBox="0 0 100 168" style="width: 100%; padding-top: 10px;">
# <symbol id='e8831993-33a8-4108-b9d4-c962f945ff97'  viewBox="0 0 512 512"><path d="M256 32C114.6 32 0 125.1 0 240c0 49.6 21.4 95 57 130.7C44.5 421.1 2.7 466 2.2 466.5c-2.2 2.3-2.8 5.7-1.5 8.7S4.8 480 8 480c66.3 0 116-31.8 140.6-51.4 32.7 12.3 69 19.4 107.4 19.4 141.4 0 256-93.1 256-208S397.4 32 256 32z"></path></symbol>
# <defs>
#
#         <marker id="end" markerWidth="5" markerHeight="4"
#                 refX="5" refY="2" orient="auto">
#             <line x1="0" y1="0" x2="5" y2="2" stroke="black"/>
#             <line x1="5" y1="2" x2="0" y2="4" stroke="black"/>
#         </marker>
#         <marker id="start" markerWidth="5" markerHeight="4"
#                 refX="0" refY="2" orient="auto">
#             <line x1="5" y1="0" x2="0" y2="2" stroke="black"/>
#             <line x1="0" y1="2" x2="5" y2="4" stroke="black"/>
#         </marker>
#
# </defs>
#
#             <use href="#e8831993-33a8-4108-b9d4-c962f945ff97" x="0.0" y="0.0" width="100.0" height="100.0" fill="rgb(240.8,240.8,240.8)" />
#
#
#             <use href="#e8831993-33a8-4108-b9d4-c962f945ff97" x="10.0" y="10.0" width="80.0" height="80.0" fill="rgb(225.6,225.6,225.6)" />
#
#
#             <use href="#e8831993-33a8-4108-b9d4-c962f945ff97" x="20.0" y="20.0" width="60.0" height="60.0" fill="rgb(210.4,210.4,210.4)" />
#
#
#             <use href="#e8831993-33a8-4108-b9d4-c962f945ff97" x="30.0" y="30.0" width="40.0" height="40.0" fill="rgb(195.2,195.2,195.2)" />
#
#
#             <use href="#e8831993-33a8-4108-b9d4-c962f945ff97" x="40.0" y="40.0" width="20.0" height="20.0" fill="rgb(180.0,180.0,180.0)" />
#
#
#         <use href="#e8831993-33a8-4108-b9d4-c962f945ff97" x="38.5" y="38.5" width="23" height="23" fill="#F1CD04" />
#
#
#         <rect x="20.0" y="148.0" fill="#ccc" width="60" height="5" rx="2" ry="2" />
#
#
#         <rect x="20.0" y="148.0" fill="#F1CD04" width="48.70570797487893" height="5" rx="2" ry="2" />
#
#
#         <text x="20.0" y="159.0" style="font-size: 6px" text-anchor="middle">23</text>
#
#
#         <text x="80.0" y="159.0" style="font-size: 6px" text-anchor="middle">24</text>
#
#
#         <rect x="15.0" y="143.0" width="70" height="21" fill="none" stroke="#ccc" stroke-width="1" />
#
#
#         <rect x="59.0" y="115.5" width="5" height="5" fill="none" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="59.0" y1="120.5" x2="15.0" y2="143.0" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="64.0" y1="120.5" x2="85.0" y2="143.0" stroke="#ccc" stroke-width="1" />
#
#
#         <line x1="38.5" y1="118.0" x2="61.5" y2="118.0" stroke="black"
#               style="marker-end: url(#end); marker-start: url(#start)"/>
#
#
#         <text x="50.0" y="112.0" style="font-size: 6px" text-anchor="middle">23</text>
#
# </svg>
# </div>
# </div>
# <div style="width: 25%; min-width: 230px; padding: 2em;">
# <div style="width: 25%; min-width:250px;">
# <p style='text-align: center;'><b>2498x Reviewing</b></p>
# <svg viewBox="0 0 100 168" style="width: 100%; padding-top: 10px;">
# <symbol id='556dfaf4-32ca-4339-af2f-c4ea66d4afb5'  aria-hidden="true" focusable="false" data-prefix="fas" data-icon="heart" class="svg-inline--fa fa-heart fa-w-16" role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 512 512"><path d="M462.3 62.6C407.5 15.9 326 24.3 275.7 76.2L256 96.5l-19.7-20.3C186.1 24.3 104.5 15.9 49.7 62.6c-62.8 53.6-66.1 149.8-9.9 207.9l193.5 199.8c12.5 12.9 32.8 12.9 45.3 0l193.5-199.8c56.3-58.1 53-154.3-9.8-207.9z"></path></symbol>
# <defs>
#
#         <marker id="end" markerWidth="5" markerHeight="4"
#                 refX="5" refY="2" orient="auto">
#             <line x1="0" y1="0" x2="5" y2="2" stroke="black"/>
#             <line x1="5" y1="2" x2="0" y2="4" stroke="black"/>
#         </marker>
#         <marker id="start" markerWidth="5" markerHeight="4"
#                 refX="0" refY="2" orient="auto">
#             <line x1="5" y1="0" x2="0" y2="2" stroke="black"/>
#             <line x1="0" y1="2" x2="5" y2="4" stroke="black"/>
#         </marker>
#
# </defs>
#
#             <use href="#556dfaf4-32ca-4339-af2f-c4ea66d4afb5" x="0.0" y="0.0" width="100.0" height="100.0" fill="rgb(240.8,240.8,240.8)" />
#
#
#             <use href="#556dfaf4-32ca-4339-af2f-c4ea66d4afb5" x="10.0" y="10.0" width="80.0" height="80.0" fill="rgb(225.6,225.6,225.6)" />
#
#
#             <use href="#556dfaf4-32ca-4339-af2f-c4ea66d4afb5" x="20.0" y="20.0" width="60.0" height="60.0" fill="rgb(210.4,210.4,210.4)" />
#
#
#             <use href="#556dfaf4-32ca-4339-af2f-c4ea66d4afb5" x="30.0" y="30.0" width="40.0" height="40.0" fill="rgb(195.2,195.2,195.2)" />
